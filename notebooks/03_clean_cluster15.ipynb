# %% [markdown]
# # Clean Cluster 15

# %% [markdown]
# ### Imports

# %%
import sys
from pathlib import Path
import pandas as pd
import numpy as np
from IPython.display import display, Markdown

# %% [markdown]
# ### Define Paths

# %%
CWD = Path.cwd()
ROOT = CWD.parent if CWD.name.lower() == "notebooks" else CWD

DATA = ROOT / "data"
RAW = DATA / "raw"
PROCESSED = DATA / "processed"

RAW.mkdir(parents=True, exist_ok=True)
PROCESSED.mkdir(parents=True, exist_ok=True)

print("Python:", sys.version.split()[0])
print("RAW:", RAW)
print("PROCESSED:", PROCESSED)
# Out:
# Python: 3.11.9
# RAW: C:\Users\danci\Interconnection-Queue-Intelligence\Interconnection-Queue-Intelligence\data\raw
# PROCESSED: C:\Users\danci\Interconnection-Queue-Intelligence\Interconnection-Queue-Intelligence\data\processed

# %% [markdown]
# ### Select Cluster 15 File

# %%
raw_files = sorted([p for p in RAW.iterdir() if p.is_file() and not p.name.startswith("~$")])

candidates = [p for p in raw_files if ("cluster" in p.name.lower() and "15" in p.name.lower())]
cluster15_path = candidates[0] if candidates else None

print("Detected:", cluster15_path.name if cluster15_path else None)
if cluster15_path is None:
    raise FileNotFoundError("Could not find Cluster 15 file. Make sure filename includes 'cluster' and '15'.")
# Out:
# Detected: cluster-15-interconnection-requests.xlsx

# %% [markdown]
# ### Helpers

# %%
def coerce_float(x):
    if pd.isna(x): return np.nan
    s = str(x).strip().replace(",", "")
    if s == "": return np.nan
    return pd.to_numeric(s, errors="coerce")

def clean_text(x):
    if pd.isna(x): return ""
    return str(x).strip()

def parse_dt(series):
    return pd.to_datetime(series, errors="coerce")

def normalize_tech(x):
    s = clean_text(x).lower()
    if s == "": return ""
    if any(k in s for k in ["battery", "storage", "bess"]): return "storage"
    if any(k in s for k in ["solar", "pv", "photovoltaic"]): return "solar"
    if "wind" in s: return "wind"
    return clean_text(x)

# %% [markdown]
# ### Load Sheets

# %%
xls = pd.ExcelFile(cluster15_path)
display(Markdown(f"**Workbook:** `{cluster15_path.name}`"))
display(pd.DataFrame({"sheet_in_file": xls.sheet_names}))

sheet_active = xls.sheet_names[0]
sheet_withdrawn = xls.sheet_names[1]

print("Using active sheet:", sheet_active)
print("Using withdrawn sheet:", sheet_withdrawn)

df15_active_raw = pd.read_excel(cluster15_path, sheet_name=sheet_active)
df15_withdrawn_raw = pd.read_excel(cluster15_path, sheet_name=sheet_withdrawn)

display(pd.DataFrame({
    "sheet": ["active", "withdrawn"],
    "rows": [len(df15_active_raw), len(df15_withdrawn_raw)],
    "cols": [df15_active_raw.shape[1], df15_withdrawn_raw.shape[1]],
}))
# Out:
# **Workbook:** `cluster-15-interconnection-requests.xlsx`
#   sheet_in_file
# 0   Cluster 15
# 1     Withdrawn
# Using active sheet: Cluster 15
# Using withdrawn sheet: Withdrawn
#        sheet  rows  cols
# 0     active   108    20
# 1  withdrawn    62    21

# %% [markdown]
# ## Standardize Column Names

# %%
display(Markdown("**Active columns:**"))
display(pd.DataFrame({"column": df15_active_raw.columns.astype(str).tolist()}))

display(Markdown("**Withdrawn columns:**"))
display(pd.DataFrame({"column": df15_withdrawn_raw.columns.astype(str).tolist()}))

display(Markdown("**Active preview:**"))
display(df15_active_raw.head(3))

display(Markdown("**Withdrawn preview:**"))
display(df15_withdrawn_raw.head(3))
# Out:
# **Active columns:**
#                column
# 0        Queue Number
# 1      Project Number
# 2        Project Name
# 3   Generation/Fuel 1
# 4            NET MW 1
# 5   Generation/Fuel 2
# 6            NET MW 2
# 7   Generation/Fuel 3
# 8            NET MW 3
# 9          NET MW POI
# 10     PROJECT COUNTY
# 11      Project State
# 12         Study Area
# 13                PTO
# 14                POI
# 15         Voltage kV
# 16      Requested COD
# 17        Queue Date
# 18   Application Date
# 19       Service Type
# **Withdrawn columns:**
#                column
# 0        Queue Number
# 1      Project Number
# 2        Project Name
# 3   Generation/Fuel 1
# 4            NET MW 1
# 5   Generation/Fuel 2
# 6            NET MW 2
# 7   Generation/Fuel 3
# 8            NET MW 3
# 9          NET MW POI
# 10     PROJECT COUNTY
# 11      Project State
# 12         Study Area
# 13                PTO
# 14                POI
# 15         Voltage kV
# 16      Requested COD
# 17         Queue Date
# 18  Application Date
# 19    Withdrawal Date
# 20       Service Type
# **Active preview:**
#    Queue Number  Project Number                  Project Name  \
# 0          2207           54516  Alisa Solar Energy Complex 2
# 1          2328           54934                       Amanece
# 2          2322           55045          Ambar Energy Storage
#
#     Generation/Fuel 1    NET MW 1 Generation/Fuel 2    NET MW 2  \
# 0  Photovoltaic/Solar  500.000000   Storage/Battery  500.000000
# 1  Photovoltaic/Solar  418.992798   Storage/Battery  416.545013
# 2     Storage/Battery  504.900000               NaN         NaN
#
#   Generation/Fuel 3  NET MW 3  NET MW POI  PROJECT COUNTY Project State  \
# 0               NaN       NaN      500.00            Yuma            AZ
# 1               NaN       NaN      400.00      Stanislaus            CA
# 2               NaN       NaN      500.01  San Bernardino            CA
#
#     Study Area   PTO                                           POI  \
# 0    SAN DIEGO  SDGE  NORTH GILA - HOODOO WASH (SDGE Portion Only)
# 1  PG&E FRESNO  PGAE             QUINTO SW STA- FINK SW STA 230 kV
# 2    SCE METRO   SCE                                   LUGO 500 kV
#
#    Voltage kV Requested COD Queue Date  Application Date  \
# 0         525    2030-06-01  2025-02-12       2024-11-18
# 1         230    2029-07-31  2025-02-12       2024-11-21
# 2         500    2030-06-01  2025-02-12       2024-11-21
#
#                                     Service Type
# 0                          Energy Only Requested
# 1  Full Capacity Deliverability Status Requested
# 2  Full Capacity Deliverability Status Requested
# **Withdrawn preview:**
#    Queue Number  Project Number  Project Name   Generation/Fuel 1  NET MW 1  \
# 0          2229           54899    Clay Flats     Storage/Battery   437.080
# 1          2202           55018        Gibson     Storage/Battery   154.598
# 2          2283           54729  Amargosa SEZ  Photovoltaic/Solar   510.350
#
#   Generation/Fuel 2  NET MW 2  Generation/Fuel 3  NET MW 3  NET MW POI  ...  \
# 0               NaN       NaN                NaN       NaN       425.0  ...
# 1               NaN       NaN                NaN       NaN       150.0  ...
# 2   Storage/Battery    508.19                NaN       NaN       500.0  ...
#
#   Project State   Study Area   PTO                         POI Voltage kV  \
# 0            CA  PG&E FRESNO  LSPC              MANNING 500 kV        500
# 1            CA  PG&E FRESNO  PGAE  MERCY SPRINGS SW STA 70 kV         70
# 2            NV      SCE EOP   GLW               BEATTY 230 kV        230
#
#    Requested COD Queue Date Application Date  Withdrawal Date  \
# 0     2030-10-01 2025-02-12        2024-11-22      2025-04-23
# 1     2028-04-14 2025-02-12        2024-11-15      2025-04-24
# 2     2030-12-01 2025-02-12        2024-11-18      2025-04-25
#
#                                         Service Type
# 0                              Energy Only Requested
# 1                              Energy Only Requested
# 2  Merchant- Full Capacity Deliverability Status ...
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Rename Mapping

# %%
RENAME_15 = {
    "Queue Number": "queue_id",
    "Project Number": "project_number",
    "Project Name": "project_name",

    "Generation/Fuel 1": "tech_1",
    "NET MW 1": "mw_1",
    "Generation/Fuel 2": "tech_2",
    "NET MW 2": "mw_2",
    "Generation/Fuel 3": "tech_3",
    "NET MW 3": "mw_3",

    "NET MW POI": "mw_poi",

    "PROJECT COUNTY": "county",
    "Project State": "state",

    "Study Area": "study_area",
    "PTO": "pto",
    "POI": "poi",
    "Voltage kV": "voltage_kv",

    "Requested COD": "date_cod_requested",
    "Queue Date": "date_queue",
    "Application Date": "date_application",

    "Service Type": "service_type",
}

RENAME_15_WITHDRAWN_OPTIONAL = {
    "Withdrawn Date": "date_withdrawn",
    "Withdrawal Date": "date_withdrawn",
    "Reason for Withdrawal": "withdraw_reason",
    "Withdrawal Reason": "withdraw_reason",
}

# %% [markdown]
# ### Standardize Function

# %%
def standardize_cluster15(df_raw: pd.DataFrame, outcome: str):
    rename = {k: v for k, v in RENAME_15.items() if k in df_raw.columns}

    if outcome == "withdrawn":
        rename.update({k: v for k, v in RENAME_15_WITHDRAWN_OPTIONAL.items() if k in df_raw.columns})

    df = df_raw.rename(columns=rename).copy()

    # Identity
    df["source"] = "cluster15"
    df["sheet_outcome"] = outcome

    # placeholder for schema compatibility (clusters don't have public-style status labels)
    df["status_raw"] = ""

    # Clean strings
    for c in ["queue_id", "project_number", "project_name", "county", "state", "study_area", "pto", "poi", "service_type", "withdraw_reason", "status_raw"]:
        if c in df.columns:
            df[c] = df[c].apply(clean_text)

    # Normalize tech slots
    for t in ["tech_1", "tech_2", "tech_3"]:
        if t in df.columns:
            df[t] = df[t].apply(normalize_tech)

    # Coerce numeric
    for m in ["mw_1", "mw_2", "mw_3", "mw_poi", "voltage_kv"]:
        if m in df.columns:
            df[m] = df[m].apply(coerce_float)

    # Parse dates
    for d in ["date_queue", "date_application", "date_cod_requested", "date_withdrawn"]:
        if d in df.columns:
            df[d] = parse_dt(df[d])

    # Canonical ordering
    CANON_COLS = [
        "source", "sheet_outcome",
        "queue_id", "project_number", "project_name",
        "pto", "study_area", "poi", "voltage_kv",
        "county", "state",
        "tech_1", "mw_1", "tech_2", "mw_2", "tech_3", "mw_3",
        "mw_poi",
        "date_queue", "date_application", "date_cod_requested", "date_withdrawn",
        "service_type",
        "withdraw_reason",
        "status_raw",
    ]
    CANON_COLS = [c for c in CANON_COLS if c in df.columns]
    return df[CANON_COLS].copy()

# %% [markdown]
# ### Standardize Both Sheets

# %%
df15_active = standardize_cluster15(df15_active_raw, outcome="active")
df15_withdrawn = standardize_cluster15(df15_withdrawn_raw, outcome="withdrawn")

df15_all = pd.concat([df15_active, df15_withdrawn], ignore_index=True)

display(pd.DataFrame({
    "outcome": ["active", "withdrawn", "ALL"],
    "rows": [len(df15_active), len(df15_withdrawn), len(df15_all)],
    "cols": [df15_active.shape[1], df15_withdrawn.shape[1], df15_all.shape[1]],
}))

display(df15_all.head(3))
# Out:
#      outcome  rows  cols
# 0     active   108    22
# 1  withdrawn    62    23
# 2        ALL   170    24
#       source sheet_outcome queue_id project_number  \
# 0  cluster15        active     2207          54516
# 1  cluster15        active     2328          54934
# 2  cluster15        active     2322          55045
#
#                    project_name   pto   study_area  \
# 0  Alisa Solar Energy Complex 2  SDGE    SAN DIEGO
# 1                       Amanece  PGAE  PG&E FRESNO
# 2          Ambar Energy Storage   SCE    SCE METRO
#
#                                             poi  voltage_kv          county  \
# 0  NORTH GILA - HOODOO WASH (SDGE Portion Only)         525            Yuma
# 1             QUINTO SW STA- FINK SW STA 230 kV         230      Stanislaus
# 2                                   LUGO 500 kV         500  San Bernardino
#
#    ...        mw_2 tech_3  mw_3  mw_poi  date_application date_cod_requested  \
# 0  ...  500.000000          NaN  500.00        2024-11-18         2030-06-01
# 1  ...  416.545013          NaN  400.00        2024-11-21         2029-07-31
# 2  ...         NaN          NaN  500.01        2024-11-21         2030-06-01
#
#                                     service_type  status_raw date_queue  \
# 0                          Energy Only Requested                    NaT
# 1  Full Capacity Deliverability Status Requested                    NaT
# 2  Full Capacity Deliverability Status Requested                    NaT
#
#   date_withdrawn
# 0            NaT
# 1            NaT
# 2            NaT
#
# [3 rows x 24 columns]

# %% [markdown]
# ### Overlap Check

# %%
if "queue_id" in df15_active.columns and "queue_id" in df15_withdrawn.columns:
    a = set(df15_active["queue_id"].dropna().unique())
    w = set(df15_withdrawn["queue_id"].dropna().unique())
    overlap = sorted(list(a.intersection(w)))

    print("Active unique queue_id:", len(a))
    print("Withdrawn unique queue_id:", len(w))
    print("Overlap queue_id:", len(overlap))

    if overlap:
        display(Markdown("**Example overlaps (first 20):**"))
        display(pd.DataFrame({"queue_id_overlap": overlap[:20]}))
else:
    print("queue_id missing in one of the sheets; cannot compute overlap cleanly.")
# Out:
# Active unique queue_id: 108
# Withdrawn unique queue_id: 62
# Overlap queue_id: 0

# %% [markdown]
# ### QA Checks

# %%
fields = ["mw_poi", "voltage_kv", "date_queue", "date_application", "date_cod_requested", "date_withdrawn", "pto", "study_area", "poi"]
qa = []
for f in fields:
    if f in df15_all.columns:
        qa.append((f, df15_all[f].isna().mean(), df15_all[f].nunique(dropna=True)))
display(pd.DataFrame(qa, columns=["field", "share_missing", "n_unique"]))

if "mw_poi" in df15_all.columns:
    display(Markdown("**MW POI by outcome:**"))
    display(df15_all.groupby("sheet_outcome")["mw_poi"].describe())

if "tech_1" in df15_all.columns:
    display(Markdown("**Tech slot 1 by outcome:**"))
    display(df15_all.groupby("sheet_outcome")["tech_1"].value_counts(dropna=False).to_frame("count"))
# Out:
#                 field  share_missing  n_unique
# 0              mw_poi       0.000000        60
# 1          voltage_kv       0.000000         8
# 2          date_queue       0.635294         1
# 3    date_application       0.364706        18
# 4  date_cod_requested       0.000000        65
# 5      date_withdrawn       0.635294        26
# 6                 pto       0.000000         8
# 7          study_area       0.000000        10
# 8                 poi       0.000000        93
# **MW POI by outcome:**
#                count        mean         std   min    25%    50%    75%  \
# sheet_outcome
# active         108.0  344.862963  254.690732  12.5  187.5  300.0  460.0
# withdrawn       62.0  351.088871  250.519886   0.0  153.0  325.0  500.0
#
#                   max
# sheet_outcome
# active         1150.0
# withdrawn      1150.0
# **Tech slot 1 by outcome:**
#                                count
# sheet_outcome tech_1
# active        storage             55
#               solar               50
#               wind                 3
# withdrawn     storage             41
#               solar               20
#               Biomass/Biofuel      1

# %% [markdown]
# ### Save Outputs

# %%
out_combined = PROCESSED / "cluster15_clean_combined.csv"
df15_all.to_csv(out_combined, index=False)

out_active = PROCESSED / "cluster15_clean_active.csv"
out_withdrawn = PROCESSED / "cluster15_clean_withdrawn.csv"
df15_active.to_csv(out_active, index=False)
df15_withdrawn.to_csv(out_withdrawn, index=False)

display(df15_all.head(50))
# Out:
#        source sheet_outcome queue_id project_number  \
# 0   cluster15        active     2207          54516
# 1   cluster15        active     2328          54934
# 2   cluster15        active     2322          55045
# 3   cluster15        active     2244          54963
# 4   cluster15        active     2204          54897
# 5   cluster15        active     2212          54730
# 6   cluster15        active     2219          54767
# 7   cluster15        active     2349          54509
# 8   cluster15        active     2305          54761
# 9   cluster15        active     2333          55013
# 10  cluster15        active     2298          54694
# 11  cluster15        active     2248          54657
# 12  cluster15        active     2206          54655
# 13  cluster15        active     2208          54656
# 14  cluster15        active     2265          54850
# 15  cluster15        active     2257          54523
# 16  cluster15        active     2308          54518
# 17  cluster15        active     2336          54696
# 18  cluster15        active     2359          54697
# 19  cluster15        active     2353          54724
# 20  cluster15        active     2280          54771
# 21  cluster15        active     2370          54809
# 22  cluster15        active     2261          54721
# 23  cluster15        active     2306          55012
# 24  cluster15        active     2277          54640
# 25  cluster15        active     2339          54511
# 26  cluster15        active     2227          54896
# 27  cluster15        active     2226          54667
# 28  cluster15        active     2344          54593
# 29  cluster15        active     2350          55001
# 30  cluster15        active     2210          54939
# 31  cluster15        active     2286          54774
# 32  cluster15        active     2304          54914
# 33  cluster15        active     2351          54526
# 34  cluster15        active     2342          54960
# 35  cluster15        active     2221          54840
# 36  cluster15        active     2224          54674
# 37  cluster15        active     2216          54862
# 38  cluster15        active     2323          54719
# 39  cluster15        active     2209          54643
# 40  cluster15        active     2297          54693
# 41  cluster15        active     2325          54577
# 42  cluster15        active     2300          54629
# 43  cluster15        active     2223          54916
# 44  cluster15        active     2273          54768
# 45  cluster15        active     2313          54702
# 46  cluster15        active     2238          54945
# 47  cluster15        active     2368          54832
# 48  cluster15        active     2220          54740
# 49  cluster15        active     2262          54725
#
#                     project_name   pto    study_area  \
# 0   Alisa Solar Energy Complex 2  SDGE     SAN DIEGO
# 1                        Amanece  PGAE   PG&E FRESNO
# 2           Ambar Energy Storage   SCE     SCE METRO
# 3                      Annapurna  PGAE   PG&E FRESNO
# 4                         Antlia  PGAE      PG&E GBA
# 5                        Argenta   SCE       SCE NOL
# 6                    Argos Solar   SCE       SCE NOL
# 7                       Aviation   SCE     SCE METRO
# 8                         Bajada   SCE   SCE EASTERN
# 9        Belterra Energy Storage  PGAE      PG&E GBA
# 10                     Blue Star  PGAE   PG&E FRESNO
# 11                          Bolt  LSPC   PG&E FRESNO
# 12                Bonita Bateria  SDGE     SAN DIEGO
# 13              Bonita Bateria 2  SDGE     SAN DIEGO
# 14                           Box   SCE   SCE EASTERN
# 15                   Bristlecone   GLW       SCE EOP
# 16                     Broadview  WAPA   PG&E FRESNO
# 17                    Brown Bear  PGAE   PG&E FRESNO
# 18       Brundage Energy Storage   SCE  SCE NORTHERN
# 19           Cabrera Reliability   SCE     SCE METRO
# 20                        Cantus  PGAE   PG&E FRESNO
# 21             Carissalito Creek  PGAE   PG&E FRESNO
# 22                        Cassia  PGAE      PG&E GBA
# 23        Chronos Energy Storage   SCE     SCE METRO
# 24                      Circinus  PGAE   PG&E FRESNO
# 25                      Comstock   SCE     SCE METRO
# 26      Conduit Energy Storage 2   SCE     SCE METRO
# 27                     Container   GLW       SCE EOP
# 28                        Cowboy  PGAE     PG&E NGBA
# 29                       Crusade   SCE     SCE METRO
# 30              Domestic Chicken  SDGE     SAN DIEGO
# 31                     Dove Cove  PGAE      PG&E GBA
# 32                         Droga  PGAE   PG&E FRESNO
# 33                         Duran   SCE     SCE METRO
# 34                   East Wonder  PGAE   PG&E FRESNO
# 35        Emerita Energy Storage  PGAE      PG&E GBA
# 36       Energia Sierra Juarez 4  SDGE     SAN DIEGO
# 37                          Fika  PGAE   PG&E FRESNO
# 38                        Fontus   SCE     SCE METRO
# 39                        Fornax  PGAE   PG&E FRESNO
# 40                     Galadriel  PGAE      PG&E GBA
# 41               Galicia Storage   SCE     SCE METRO
# 42                         GAMAY  PGAE     PG&E KERN
# 43                         Geras  PGAE   PG&E FRESNO
# 44                      Goldlink   GLW       SCE EOP
# 45         Gosford Solar Storage  PGAE     PG&E KERN
# 46                   Grapevine 1   GLW       SCE EOP
# 47                   Green Palms   SCE   SCE EASTERN
# 48                      Hacienda   SCE       SCE NOL
# 49       Helios Grid Reliability  PGAE      PG&E GBA
#
#                                              poi  voltage_kv  \
# 0   NORTH GILA - HOODOO WASH (SDGE Portion Only)         525
# 1              QUINTO SW STA- FINK SW STA 230 kV         230
# 2                                    LUGO 500 kV         500
# 3                           QUINTO SW STA 230 kV         230
# 4                         MOSS LANDING PP 115 kV         115
# 5                                  PISGAH 230 kV         230
# 6                                 CALCITE 230 kV         230
# 7                                    LUGO 500 kV         500
# 8                               RED BLUFF 230 kV         230
# 9                                 BELLOTA 230 kV         230
# 10                        DRY LAKE SW STA 500 kV         500
# 11                                MANNING 500 kV         500
# 12                                 TALEGA 138 kV         138
# 13                              MARGARITA 138 kV         138
# 14                              RED BLUFF 230 kV         230
# 15                          VALLEY SWITCH 230 kV         230
# 16                            LOS BANOS-GATES #3         500
# 17                        DRY LAKE SW STA 500 kV         500
# 18                               ANTELOPE 230 kV         230
# 19                                   LUGO 500 kV         500
# 20                            FINK SW STA 230 kV         230
# 21                              LOS BANOS 500 kV         500
# 22                                LAMMERS 115 kV         115
# 23                                   LUGO 500 kV         500
# 24                               LE GRAND 115 kV         115
# 25                                   LUGO 500 kV         500
# 26                                   LUGO 500 kV         500
# 27                          VALLEY SWITCH 230 kV         230
# 28                               DELEVAN-CORTINA         230
# 29                                  VIEJO 230 kV         230
# 30                             HASSAYAMPA 500 kV         500
# 31                                  TESLA 500 kV         500
# 32                          QUINTO SW STA 230 kV         230
# 33                                   LUGO 500 kV         500
# 34                        DRY LAKE SW STA 500 kV         500
# 35                                  TESLA 230 kV         230
# 36                            EAST COUNTY 230 kV         230
# 37                          QUINTO SW STA 230 kV         230
# 38                           RANCHO VISTA 230 kV         230
# 39                    TRANQUILLITY SW STA 230 kV         230
# 40                                  TESLA 230 kV         230
# 41                                   LUGO 500 kV         500
# 42                                   ARCO-MIDWAY         230
# 43                            FINK SW STA 230 kV         230
# 44                       LATHROP 230 kV (FUTURE)         230
# 45                     BITTERWATER SW STA 230 kV         230
# 46                          VALLEY SWITCH 230 kV         230
# 47                         COLORADO RIVER 230 kV         230
# 48                                 PISGAH 230 kV         230
# 49                              LOCKEFORD 115 kV         115
#
#                county  ...        mw_2 tech_3  mw_3   mw_poi  \
# 0                Yuma  ...  500.000000          NaN   500.00
# 1          Stanislaus  ...  416.545013          NaN   400.00
# 2      San Bernardino  ...         NaN          NaN   500.01
# 3       Merced County  ...         NaN          NaN   250.00
# 4            Monterey  ...         NaN          NaN   199.00
# 5      San Bernardino  ...         NaN          NaN   150.01
# 6       San Bernadino  ...         NaN          NaN   350.12
# 7      San Bernardino  ...  600.000000          NaN   600.00
# 8           Riverside  ...         NaN          NaN   350.00
# 9           Calaveras  ...         NaN          NaN   500.00
# 10              Kings  ...  206.802262          NaN   300.00
# 11             Fresno  ...  253.800000          NaN   250.00
# 12             Orange  ...         NaN          NaN   100.00
# 13             Orange  ...         NaN          NaN   120.00
# 14          Riverside  ...         NaN          NaN    60.00
# 15                Nye  ...  460.140000          NaN   450.00
# 16             Fresno  ...  491.800000          NaN   800.00
# 17              Kings  ...  303.785000          NaN   300.00
# 18        Los Angeles  ...         NaN          NaN   197.00
# 19     San Bernardino  ...         NaN          NaN   199.00
# 20             Merced  ...  249.524000          NaN   240.00
# 21             Merced  ...  415.860000          NaN   400.00
# 22        San Joaquin  ...         NaN          NaN    99.00
# 23     San Bernardino  ...         NaN          NaN   500.00
# 24             Merced  ...  185.643000          NaN   180.00
# 25     San Bernardino  ...  199.000000          NaN   199.00
# 26     San Bernardino  ...         NaN          NaN   199.00
# 27                Nye  ...         NaN          NaN   200.00
# 28             Colusa  ...  155.300000          NaN   150.00
# 29             Orange  ...         NaN          NaN  1000.00
# 30           Maricopa  ...         NaN          NaN   550.01
# 31        San Joaquin  ...         NaN          NaN   500.00
# 32      Merced County  ...         NaN          NaN   100.00
# 33     San Bernardino  ...  300.000000          NaN   300.00
# 34               Kern  ...  188.820000          NaN   350.00
# 35            Alameda  ...         NaN          NaN   199.90
# 36    Tijuana, Mexico  ...         NaN          NaN   299.80
# 37             Merced  ...         NaN          NaN   250.00
# 38     San Bernardino  ...         NaN          NaN   500.00
# 39             Fresno  ...  103.125000          NaN   100.00
# 40             Madera  ...         NaN          NaN   300.00
# 41     San Bernardino  ...         NaN          NaN   490.00
# 42               KERN  ...  200.000000          NaN   200.00
# 43  Stanislaus County  ...  133.760000          NaN   130.00
# 44                Nye  ...         NaN          NaN   350.00
# 45               Kern  ...         NaN          NaN   300.00
# 46                Nye  ...         NaN          NaN   200.01
# 47          Riverside  ...         NaN          NaN   300.62
# 48     San Bernardino  ...         NaN          NaN   150.00
# 49          Calaveras  ...         NaN          NaN   199.00
#
#     date_application date_cod_requested  \
# 0         2024-11-18         2030-06-01
# 1         2024-11-21         2029-07-31
# 2         2024-11-21         2030-06-01
# 3         2024-11-20         2028-06-01
# 4         2024-11-19         2031-12-01
# 5         2024-11-20         2031-05-01
# 6         2024-11-15         2030-06-01
# 7         2024-11-18         2028-08-01
# 8         2024-11-15         2030-06-01
# 9         2024-11-19         2028-04-01
# 10        2024-11-21         2029-03-30
# 11        2024-11-21         2031-05-01
# 12        2024-11-19         2029-05-31
# 13        2024-11-19         2029-05-31
# 14        2024-12-02         2029-01-01
# 15        2024-11-05         2030-06-01
# 16        2024-11-21         2028-09-01
# 17        2024-11-21         2029-03-30
# 18        2024-11-20         2029-06-01
# 19        2024-11-14         2028-09-15
# 20        2024-11-20         2031-03-14
# 21        2024-11-21         2030-12-31
# 22        2024-11-22         2031-03-31
# 23        2024-12-02         2031-11-30
# 24        2024-11-20         2031-12-01
# 25        2024-11-19         2028-08-01
# 26        2024-11-15         2031-02-26
# 27        2024-11-18         2031-06-01
# 28        2024-11-27         2030-06-30
# 29        2024-12-02         2028-12-31
# 30        2024-11-20         2029-12-03
# 31        2024-11-20         2031-03-14
# 32        2024-11-20         2028-06-01
# 33        2024-11-19         2028-08-01
# 34        2024-11-21         2029-07-31
# 35        2024-12-01         2028-03-01
# 36        2024-11-27         2030-03-31
# 37        2024-11-21         2029-06-30
# 38        2024-11-22         2031-03-31
# 39        2024-11-20         2031-12-01
# 40        2024-11-22         2031-03-31
# 41        2024-11-12         2028-10-01
# 42        2024-11-26         2031-12-31
# 43        2024-11-20         2028-06-01
# 44        2024-11-15         2030-06-01
# 45        2024-11-21         2029-03-30
# 46        2024-11-18         2031-06-01
# 47        2024-11-15         2030-12-31
# 48        2024-11-20         2030-12-01
# 49        2024-11-14         2028-09-15
#
#                                      service_type  status_raw date_queue  \
# 0                           Energy Only Requested                    NaT
# 1   Full Capacity Deliverability Status Requested                    NaT
# 2   Full Capacity Deliverability Status Requested                    NaT
# 3   Full Capacity Deliverability Status Requested                    NaT
# 4   Full Capacity Deliverability Status Requested                    NaT
# 5                           Energy Only Requested                    NaT
# 6                           Energy Only Requested                    NaT
# 7   Full Capacity Deliverability Status Requested                    NaT
# 8                           Energy Only Requested                    NaT
# 9   Full Capacity Deliverability Status Requested                    NaT
# 10  Full Capacity Deliverability Status Requested                    NaT
# 11  Full Capacity Deliverability Status Requested                    NaT
# 12  Full Capacity Deliverability Status Requested                    NaT
# 13  Full Capacity Deliverability Status Requested                    NaT
# 14                          Energy Only Requested                    NaT
# 15                          Energy Only Requested                    NaT
# 16  Full Capacity Deliverability Status Requested                    NaT
# 17  Full Capacity Deliverability Status Requested                    NaT
# 18  Full Capacity Deliverability Status Requested                    NaT
# 19  Full Capacity Deliverability Status Requested                    NaT
# 20  Full Capacity Deliverability Status Requested                    NaT
# 21  Full Capacity Deliverability Status Requested                    NaT
# 22  Full Capacity Deliverability Status Requested                    NaT
# 23  Full Capacity Deliverability Status Requested                    NaT
# 24                          Energy Only Requested                    NaT
# 25  Full Capacity Deliverability Status Requested                    NaT
# 26  Full Capacity Deliverability Status Requested                    NaT
# 27                          Energy Only Requested                    NaT
# 28                          Energy Only Requested                    NaT
# 29  Full Capacity Deliverability Status Requested                    NaT
# 30                          Energy Only Requested                    NaT
# 31  Full Capacity Deliverability Status Requested                    NaT
# 32  Full Capacity Deliverability Status Requested                    NaT
# 33  Full Capacity Deliverability Status Requested                    NaT
# 34  Full Capacity Deliverability Status Requested                    NaT
# 35  Full Capacity Deliverability Status Requested                    NaT
# 36                          Energy Only Requested                    NaT
# 37  Full Capacity Deliverability Status Requested                    NaT
# 38  Full Capacity Deliverability Status Requested                    NaT
# 39                          Energy Only Requested                    NaT
# 40  Full Capacity Deliverability Status Requested                    NaT
# 41  Full Capacity Deliverability Status Requested                    NaT
# 42                          Energy Only Requested                    NaT
# 43  Full Capacity Deliverability Status Requested                    NaT
# 44                          Energy Only Requested                    NaT
# 45                          Energy Only Requested                    NaT
# 46                          Energy Only Requested                    NaT
# 47                          Energy Only Requested                    NaT
# 48                          Energy Only Requested                    NaT
# 49  Full Capacity Deliverability Status Requested                    NaT
#
#    date_withdrawn
# 0             NaT
# 1             NaT
# 2             NaT
# 3             NaT
# 4             NaT
# 5             NaT
# 6             NaT
# 7             NaT
# 8             NaT
# 9             NaT
# 10            NaT
# 11            NaT
# 12            NaT
# 13            NaT
# 14            NaT
# 15            NaT
# 16            NaT
# 17            NaT
# 18            NaT
# 19            NaT
# 20            NaT
# 21            NaT
# 22            NaT
# 23            NaT
# 24            NaT
# 25            NaT
# 26            NaT
# 27            NaT
# 28            NaT
# 29            NaT
# 30            NaT
# 31            NaT
# 32            NaT
# 33            NaT
# 34            NaT
# 35            NaT
# 36            NaT
# 37            NaT
# 38            NaT
# 39            NaT
# 40            NaT
# 41            NaT
# 42            NaT
# 43            NaT
# 44            NaT
# 45            NaT
# 46            NaT
# 47            NaT
# 48            NaT
# 49            NaT
#
# [50 rows x 24 columns]
