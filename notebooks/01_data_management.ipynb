# %% [markdown]
# # Data Management

# %% [markdown]
# ### Imports

# %%
import sys
from pathlib import Path
import re
import csv

import pandas as pd
from IPython.display import display, Markdown

# %% [markdown]
# ### Define Paths

# %%
CWD = Path.cwd()
ROOT = CWD.parent if CWD.name.lower() == "notebooks" else CWD

DATA = ROOT / "data"
RAW = DATA / "raw"
PROCESSED = DATA / "processed"

RAW.mkdir(parents=True, exist_ok=True)
PROCESSED.mkdir(parents=True, exist_ok=True)

print("Python:", sys.version.split()[0])
print("CWD:", CWD)
print("ROOT:", ROOT)
print("RAW:", RAW)
print("PROCESSED:", PROCESSED)
# Out:
# Python: 3.11.9
# CWD: C:\Users\danci\Interconnection-Queue-Intelligence\Interconnection-Queue-Intelligence\notebooks
# ROOT: C:\Users\danci\Interconnection-Queue-Intelligence\Interconnection-Queue-Intelligence
# RAW: C:\Users\danci\Interconnection-Queue-Intelligence\Interconnection-Queue-Intelligence\data\raw
# PROCESSED: C:\Users\danci\Interconnection-Queue-Intelligence\Interconnection-Queue-Intelligence\data\processed

# %% [markdown]
# ### Helpers

# %%
def looks_like_header_cell(x) -> bool:
    if x is None or (isinstance(x, float) and pd.isna(x)):
        return False
    s = str(x).strip()
    if s == "":
        return False
    if re.fullmatch(r"[-+]?\d+(\.\d+)?", s):
        return False
    return bool(re.search(r"[A-Za-z]", s))


def detect_header_row(preview_df: pd.DataFrame, min_nonnull: int = 4) -> int:
    best_i, best_score = 0, float("-inf")

    for i in range(len(preview_df)):
        row = preview_df.iloc[i]
        nonnull = row.dropna().tolist()
        if len(nonnull) < min_nonnull:
            continue

        headerish = sum(looks_like_header_cell(v) for v in nonnull)
        norm = [str(v).strip().lower() for v in nonnull]
        dup_penalty = len(norm) - len(set(norm))

        score = len(nonnull) + 2 * headerish - 1.5 * dup_penalty
        if score > best_score:
            best_score = score
            best_i = i

    return best_i


def inspect_excel(path: Path, max_scan_rows: int = 60, head_rows: int = 5):
    display(Markdown(f"**File:** `{path.name}`"))
    if not path.exists():
        display(Markdown("**Missing file** (not found in `data/raw/`)."))
        return

    try:
        xls = pd.ExcelFile(path)
    except Exception as e:
        display(Markdown(f"**Failed to open Excel:** `{e}`"))
        return

    sheets = xls.sheet_names
    display(Markdown(f"**Sheets:** {len(sheets)}"))
    display(pd.DataFrame({"sheet": sheets}))

    for sheet in sheets:
        display(Markdown(f"#### Sheet: `{sheet}`"))

        try:
            preview = pd.read_excel(path, sheet_name=sheet, header=None, nrows=max_scan_rows)
        except Exception as e:
            display(Markdown(f"**Preview read failed:** `{e}`"))
            continue

        header_row = detect_header_row(preview)
        print(f"Detected header row (0-based in preview): {header_row}")

        try:
            df = pd.read_excel(path, sheet_name=sheet, header=header_row)
        except Exception as e:
            display(Markdown(f"**Header-based read failed:** `{e}`"))
            continue

        df = df.loc[:, ~df.columns.to_series().astype(str).str.match(r"^Unnamed:")].copy()

        cols = [str(c) for c in df.columns.tolist()]
        display(Markdown(f"Columns: **{len(cols)}**"))
        display(pd.DataFrame({"column": cols}))

        display(Markdown(f"Preview: `head({head_rows})`"))
        display(df.head(head_rows))

# %% [markdown]
# ### List Raw Files

# %%
raw_files = sorted([p for p in RAW.iterdir() if p.is_file() and not p.name.startswith("~$")])
display(pd.DataFrame({"file": [p.name for p in raw_files]}))
# Out:
#                                                 file
# 0           cluster-15-interconnection-requests.xlsx
# 1  PreliminaryCluster14ProjectListasofMay20-2021....
# 2                             publicqueuereport.xlsx

# %% [markdown]
# ## Inspect Public Queue

# %%
PUBLIC_QUEUE_FILE = "publicqueuereport.xlsx"

path = RAW / PUBLIC_QUEUE_FILE
inspect_excel(path)
# Out:
# **File:** `publicqueuereport.xlsx`
# **Sheets:** 3
#                            sheet
# 0           Grid GenerationQueue
# 1  Completed Generation Projects
# 2  Withdrawn Generation Projects
# #### Sheet: `Grid GenerationQueue`
# Detected header row (0-based in preview): 3
# Columns: **33**
#                                                column
# 0                                        Project Name
# 1                                      Queue Position
# 2               Interconnection Request\nReceive Date
# 3                                          Queue Date
# 4                                  Application Status
# 5                                      Study\nProcess
# 6                                              Type-1
# 7                                              Type-2
# 8                                              Type-3
# 9                                              Fuel-1
# 10                                             Fuel-2
# 11                                             Fuel-3
# 12                                               MW-1
# 13                                               MW-2
# 14                                               MW-3
# 15                                    Net MWs to Grid
# 16    Full Capacity, Partial or Energy Only (FC/P/EO)
# 17                          TPD Allocation Percentage
# 18          Off-Peak Deliverability and Economic Only
# 19                               TPD Allocation Group
# 20                                             County
# 21                                              State
# 22                                            Utility
# 23                                   PTO Study Region
# 24                       Station or Transmission Line
# 25         Proposed\nOn-line Date\n(as filed with IR)
# 26                              Current\nOn-line Date
# 27                                  Suspension Status
# 28           Feasibility Study or Supplemental Review
# 29     System Impact Study or \nPhase I Cluster Study
# 30  Facilities Study (FAS) or \nPhase II Cluster S...
# 31                               Optional Study\n(OS)
# 32                 Interconnection Agreement \nStatus
# Preview: `head(5)`
#                                     Project Name Queue Position  \
# 0                     MONTEZUMA (HIGH WINDS III)             22
# 1                                      TULE WIND             32
# 2                                 MIDWAY PEAKING             54
# 3          FRESNO COGENERATION EXPANSION PROJECT             61
# 4  LAKE ELSINORE ADVANCED PUMPED STORAGE PROJECT             72
#
#   Interconnection Request\nReceive Date           Queue Date  \
# 0                   2003-11-18 00:00:00  2003-11-18 08:00:00
# 1                   2004-05-12 00:00:00  2004-05-24 07:00:00
# 2                   2005-01-12 00:00:00  2005-01-12 08:00:00
# 3                   2005-03-28 00:00:00  2005-03-30 08:00:00
# 4                   2005-04-26 00:00:00  2005-06-21 07:00:00
#
#   Application Status Study\nProcess         Type-1   Type-2 Type-3  \
# 0             ACTIVE       AMEND 39   Wind Turbine  Storage    NaN
# 1             ACTIVE    Serial LGIP   Wind Turbine  Storage    NaN
# 2             ACTIVE    Serial LGIP    Gas Turbine  Storage    NaN
# 3             ACTIVE       AMEND 39  Steam Turbine  Storage    NaN
# 4             ACTIVE    Serial LGIP        Storage      NaN    NaN
#
#                  Fuel-1  ... PTO Study Region  \
# 0          Wind Turbine  ...         Northern
# 1          Wind Turbine  ...             SDGE
# 2           Natural Gas  ...           Fresno
# 3           Natural Gas  ...           Fresno
# 4  Pumped-Storage hydro  ...             SDGE
#
#           Station or Transmission Line  \
# 0                 Birds Landing 230 kV
# 1     Boulevard East Substation 138 kV
# 2                   Panoche Substation
# 3               Helm-Kerman 70 kV Line
# 4  Proposed Lee Lake Substation 500 kV
#
#    Proposed\nOn-line Date\n(as filed with IR)  Current\nOn-line Date  \
# 0                         2005-06-30 07:00:00    2024-04-01 07:00:00
# 1                         2007-09-01 07:00:00    2030-10-31 07:00:00
# 2                         2008-06-01 07:00:00    2027-06-30 07:00:00
# 3                         2006-05-31 07:00:00    2023-02-28 08:00:00
# 4                         2008-12-31 08:00:00    2028-12-31 08:00:00
#
#    Suspension Status  Feasibility Study or Supplemental Review  \
# 0                NaN                                       NaN
# 1                NaN                                    Waived
# 2                NaN                                    Waived
# 3                NaN                                       NaN
# 4                NaN                                    Waived
#
#   System Impact Study or \nPhase I Cluster Study  \
# 0                                       Complete
# 1                                       Complete
# 2                                       Complete
# 3                                       Complete
# 4                                       Complete
#
#    Facilities Study (FAS) or \nPhase II Cluster Study Optional Study\n(OS)  \
# 0                                           Complete                   NaN
# 1                                           Complete                   NaN
# 2                                           Re-Study                   NaN
# 3                                           Complete                   NaN
# 4                                           Re-Study                   NaN
#
#   Interconnection Agreement \nStatus
# 0                           Executed
# 1                           Executed
# 2                           Executed
# 3                           Executed
# 4                           Executed
#
# [5 rows x 33 columns]
# #### Sheet: `Completed Generation Projects`
# Detected header row (0-based in preview): 3
# Columns: **32**
#                                                column
# 0                                        Project Name
# 1                                      Queue Position
# 2               Interconnection Request\nReceive Date
# 3                                          Queue Date
# 4                                  Application Status
# 5                                      Study\nProcess
# 6                                              Type-1
# 7                                              Type-2
# 8                                              Type-3
# 9                                              Fuel-1
# 10                                             Fuel-2
# 11                                             Fuel-3
# 12                                               MW-1
# 13                                               MW-2
# 14                                               MW-3
# 15                                    Net MWs to Grid
# 16    Full Capacity, Partial or Energy Only (FC/P/EO)
# 17                          TPD Allocation Percentage
# 18          Off-Peak Deliverability and Economic Only
# 19                               TPD Allocation Group
# 20                                             County
# 21                                              State
# 22                                            Utility
# 23                                   PTO Study Region
# 24                       Station or Transmission Line
# 25         Proposed\nOn-line Date\n(as filed with IR)
# 26                               Actual\nOn-line Date
# 27           Feasibility Study or Supplemental Review
# 28     System Impact Study or \nPhase I Cluster Study
# 29  Facilities Study (FAS) or \nPhase II Cluster S...
# 30                               Optional Study\n(OS)
# 31                 Interconnection Agreement \nStatus
# Preview: `head(5)`
#                                         Project Name Queue Position  \
# 0                       OTAY MESA GENERATING PROJECT             1A
# 1  GATEWAY GENERATING FACILITY (FKA CONTRA COSTA ...              2
# 2               CPV SENTINEL (FKA INTERGEN OCOTILLO)              3
# 3                             PALOMAR ENERGY PROJECT              4
# 4                            NRG EL SEGUNDO - TOT041              7
#
#   Interconnection Request\nReceive Date          Queue Date  \
# 0                            1999-11-01 1999-11-01 08:00:00
# 1                            1999-08-10 2000-02-03 08:00:00
# 2                            2000-04-21 2000-06-14 07:00:00
# 3                            2000-08-08 2000-08-08 07:00:00
# 4                            2000-08-16 2000-10-06 07:00:00
#
#   Application Status  Study\nProcess          Type-1   Type-2  Type-3  \
# 0          COMPLETED  Pre- Amend. 39  Combined Cycle      NaN     NaN
# 1          COMPLETED  Pre- Amend. 39  Combined Cycle      NaN     NaN
# 2          COMPLETED     Serial LGIP     Gas Turbine  Storage     NaN
# 3          COMPLETED  Pre- Amend. 39  Combined Cycle      NaN     NaN
# 4          COMPLETED  Pre- Amend. 39  Combined Cycle      NaN     NaN
#
#         Fuel-1  ... Utility  PTO Study Region  \
# 0  Natural Gas  ...    SDGE               NaN
# 1  Natural Gas  ...    PGAE               NaN
# 2  Natural Gas  ...     SCE           Eastern
# 3  Natural Gas  ...    SDGE               NaN
# 4  Natural Gas  ...     SCE             Metro
#
#           Station or Transmission Line  \
# 0          Otay Mesa Switchyard 230 kV
# 1  Contra Costa Power Plant 230 kV bus
# 2          Devers Substation 230kV Bus
# 3     Palomar Energy Switchyard 230 kV
# 4                El Segundo 220 kV Bus
#
#    Proposed\nOn-line Date\n(as filed with IR)  Actual\nOn-line Date  \
# 0                         2002-03-01 08:00:00   2009-10-02 07:00:00
# 1                         2007-11-28 08:00:00   2009-01-06 08:00:00
# 2                         2004-01-01 08:00:00   2013-06-01 07:00:00
# 3                         2001-06-01 07:00:00   2005-10-14 07:00:00
# 4                         2009-08-01 07:00:00   2013-07-10 07:00:00
#
#    Feasibility Study or Supplemental Review  \
# 0                                       NaN
# 1                                       NaN
# 2                                    Waived
# 3                                       NaN
# 4                                       NaN
#
#   System Impact Study or \nPhase I Cluster Study  \
# 0                                       Complete
# 1                                       Complete
# 2                                       Re-Study
# 3                                       Complete
# 4                                       Complete
#
#    Facilities Study (FAS) or \nPhase II Cluster Study Optional Study\n(OS)  \
# 0                                           Complete                   NaN
# 1                                           Complete                   NaN
# 2                                           Re-Study              Complete
# 3                                           Complete                   NaN
# 4                                           Complete              Complete
#
#   Interconnection Agreement \nStatus
# 0                           Executed
# 1                           Executed
# 2                           Executed
# 3                           Executed
# 4                           Executed
#
# [5 rows x 32 columns]
# #### Sheet: `Withdrawn Generation Projects`
# Detected header row (0-based in preview): 3
# Columns: **31**
#                                                column
# 0                         Project Name - Confidential
# 1                                      Queue Position
# 2               Interconnection Request\nReceive Date
# 3                                          Queue Date
# 4                                  Application Status
# 5                                      Withdrawn Date
# 6                                      Study\nProcess
# 7                                              Type-1
# 8                                              Type-2
# 9                                              Type-3
# 10                                             Fuel-1
# 11                                             Fuel-2
# 12                                             Fuel-3
# 13                                               MW-1
# 14                                               MW-2
# 15                                               MW-3
# 16                                    Net MWs to Grid
# 17    Full Capacity, Partial or Energy Only (FC/P/EO)
# 18          Off-Peak Deliverability and Economic Only
# 19                                             County
# 20                                              State
# 21                                            Utility
# 22                       Station or Transmission Line
# 23         Proposed\nOn-line Date\n(as filed with IR)
# 24                              Current\nOn-line Date
# 25           Feasibility Study or Supplemental Review
# 26     System Impact Study or \nPhase I Cluster Study
# 27  Facilities Study (FAS) or \nPhase II Cluster S...
# 28                               Optional Study\n(OS)
# 29                 Interconnection Agreement \nStatus
# 30                              Reason for Withdrawal
# Preview: `head(5)`
#                     Project Name - Confidential Queue Position  \
# 0       ENCINA GENERATING PROJECT (PH. 1 AND 2)              5
# 1                             TESLA POWER PLANT              6
# 2  SAN DIEGO COMMUNITY POWER GENERATING STATION              8
# 3               MORRO BAY MODERNIZATION PROJECT              9
# 4                         AVENAL ENERGY PROJECT             10
#
#   Interconnection Request\nReceive Date          Queue Date  \
# 0                            2000-08-09 2000-08-09 07:00:00
# 1                            2007-08-24 2000-08-23 07:00:00
# 2                            2000-11-28 2000-11-28 08:00:00
# 3                            2000-12-01 2000-12-01 08:00:00
# 4                            2001-05-02 2001-05-02 07:00:00
#
#   Application Status      Withdrawn Date  Study\nProcess          Type-1  \
# 0          WITHDRAWN                 NaT  Pre- Amend. 39  Combined Cycle
# 1          WITHDRAWN 2011-06-16 17:56:36     Serial LGIP  Combined Cycle
# 2          WITHDRAWN                 NaT  Pre- Amend. 39  Combined Cycle
# 3          WITHDRAWN                 NaT  Pre- Amend. 39  Combined Cycle
# 4          WITHDRAWN                 NaT  Pre- Amend. 39  Combined Cycle
#
#   Type-2 Type-3  ... Utility                 Station or Transmission Line  \
# 0    NaN    NaN  ...    SDGE                Encina Power Plant Switchyard
# 1    NaN    NaN  ...    PGAE                        Tesla Sub 230kV Bus E
# 2    NaN    NaN  ...    SDGE                   Sycamore Canyon Substation
# 3    NaN    NaN  ...    PGAE                         Morro Bay Substation
# 4    NaN    NaN  ...    PGAE  Gates Substation (Arco - Gates 230 kV line)
#
#   Proposed\nOn-line Date\n(as filed with IR)  Current\nOn-line Date  \
# 0                        2003-06-30 07:00:00    2008-06-01 07:00:00
# 1                        2008-06-01 07:00:00    2014-11-30 08:00:00
# 2                        2004-06-01 07:00:00    2010-12-31 08:00:00
# 3                        2008-01-01 08:00:00    2008-01-01 08:00:00
# 4                        2009-01-01 08:00:00    2009-07-01 07:00:00
#
#    Feasibility Study or Supplemental Review  \
# 0                                       NaN
# 1                                    Waived
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    System Impact Study or \nPhase I Cluster Study  \
# 0                                        Complete
# 1                                        Complete
# 2                                        Complete
# 3                                        Complete
# 4                                        Complete
#
#    Facilities Study (FAS) or \nPhase II Cluster Study Optional Study\n(OS)  \
# 0                                                NaN                   NaN
# 1                                           Complete              Complete
# 2                                           Re-Study                   NaN
# 3                                           Complete                   NaN
# 4                                           Complete                   NaN
#
#   Interconnection Agreement \nStatus Reason for Withdrawal
# 0                                NaN                   NaN
# 1                                NaN                   NaN
# 2                        In Progress                   NaN
# 3                           Executed                   NaN
# 4                           Executed                   NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Inspect Cluster 15

# %%
CLUSTER15_FILE = "cluster-15-interconnection-requests.xlsx"

path = RAW / CLUSTER15_FILE
inspect_excel(path)
# Out:
# **File:** `cluster-15-interconnection-requests.xlsx`
# **Sheets:** 2
#          sheet
# 0  Cluster 15
# 1    Withdrawn
# #### Sheet: `Cluster 15 `
# Detected header row (0-based in preview): 0
# Columns: **20**
#                column
# 0        Queue Number
# 1      Project Number
# 2        Project Name
# 3   Generation/Fuel 1
# 4            NET MW 1
# 5   Generation/Fuel 2
# 6            NET MW 2
# 7   Generation/Fuel 3
# 8            NET MW 3
# 9          NET MW POI
# 10     PROJECT COUNTY
# 11      Project State
# 12         Study Area
# 13                PTO
# 14                POI
# 15         Voltage kV
# 16      Requested COD
# 17        Queue Date
# 18   Application Date
# 19       Service Type
# Preview: `head(5)`
#    Queue Number  Project Number                  Project Name  \
# 0          2207           54516  Alisa Solar Energy Complex 2
# 1          2328           54934                       Amanece
# 2          2322           55045          Ambar Energy Storage
# 3          2244           54963                     Annapurna
# 4          2204           54897                        Antlia
#
#     Generation/Fuel 1    NET MW 1 Generation/Fuel 2    NET MW 2  \
# 0  Photovoltaic/Solar  500.000000   Storage/Battery  500.000000
# 1  Photovoltaic/Solar  418.992798   Storage/Battery  416.545013
# 2     Storage/Battery  504.900000               NaN         NaN
# 3     Storage/Battery  257.000000               NaN         NaN
# 4     Storage/Battery  204.859000               NaN         NaN
#
#   Generation/Fuel 3  NET MW 3  NET MW POI  PROJECT COUNTY Project State  \
# 0               NaN       NaN      500.00            Yuma            AZ
# 1               NaN       NaN      400.00      Stanislaus            CA
# 2               NaN       NaN      500.01  San Bernardino            CA
# 3               NaN       NaN      250.00   Merced County            CA
# 4               NaN       NaN      199.00        Monterey            CA
#
#     Study Area   PTO                                           POI  \
# 0    SAN DIEGO  SDGE  NORTH GILA - HOODOO WASH (SDGE Portion Only)
# 1  PG&E FRESNO  PGAE             QUINTO SW STA- FINK SW STA 230 kV
# 2    SCE METRO   SCE                                   LUGO 500 kV
# 3  PG&E FRESNO  PGAE                          QUINTO SW STA 230 kV
# 4     PG&E GBA  PGAE                        MOSS LANDING PP 115 kV
#
#    Voltage kV Requested COD Queue Date  Application Date  \
# 0         525    2030-06-01  2025-02-12       2024-11-18
# 1         230    2029-07-31  2025-02-12       2024-11-21
# 2         500    2030-06-01  2025-02-12       2024-11-21
# 3         230    2028-06-01  2025-02-12       2024-11-20
# 4         115    2031-12-01  2025-02-12       2024-11-19
#
#                                     Service Type
# 0                          Energy Only Requested
# 1  Full Capacity Deliverability Status Requested
# 2  Full Capacity Deliverability Status Requested
# 3  Full Capacity Deliverability Status Requested
# 4  Full Capacity Deliverability Status Requested
# #### Sheet: `Withdrawn`
# Detected header row (0-based in preview): 0
# Columns: **21**
#                column
# 0        Queue Number
# 1      Project Number
# 2        Project Name
# 3   Generation/Fuel 1
# 4            NET MW 1
# 5   Generation/Fuel 2
# 6            NET MW 2
# 7   Generation/Fuel 3
# 8            NET MW 3
# 9          NET MW POI
# 10     PROJECT COUNTY
# 11      Project State
# 12         Study Area
# 13                PTO
# 14                POI
# 15         Voltage kV
# 16      Requested COD
# 17         Queue Date
# 18  Application Date
# 19    Withdrawal Date
# 20       Service Type
# Preview: `head(5)`
#    Queue Number  Project Number          Project Name   Generation/Fuel 1  \
# 0          2229           54899            Clay Flats     Storage/Battery
# 1          2202           55018                Gibson     Storage/Battery
# 2          2283           54729          Amargosa SEZ  Photovoltaic/Solar
# 3          2228           54946           Grapevine 2     Storage/Battery
# 4          2290           54668  Ashton Energy Center  Photovoltaic/Solar
#
#    NET MW 1 Generation/Fuel 2  NET MW 2  Generation/Fuel 3  NET MW 3  \
# 0   437.080               NaN       NaN                NaN       NaN
# 1   154.598               NaN       NaN                NaN       NaN
# 2   510.350   Storage/Battery    508.19                NaN       NaN
# 3   505.100               NaN       NaN                NaN       NaN
# 4  1026.670   Storage/Battery   1022.47                NaN       NaN
#
#    NET MW POI  ... Project State   Study Area   PTO  \
# 0       425.0  ...            CA  PG&E FRESNO  LSPC
# 1       150.0  ...            CA  PG&E FRESNO  PGAE
# 2       500.0  ...            NV      SCE EOP   GLW
# 3       500.0  ...            NV      SCE EOP   SCE
# 4      1000.0  ...            NV      SCE EOP   GLW
#
#                           POI Voltage kV  Requested COD Queue Date  \
# 0              MANNING 500 kV        500     2030-10-01 2025-02-12
# 1  MERCY SPRINGS SW STA 70 kV         70     2028-04-14 2025-02-12
# 2               BEATTY 230 kV        230     2030-12-01 2025-02-12
# 3             ELDORADO 230 kV        230     2028-06-01 2025-02-12
# 4        VALLEY SWITCH 230 kV        230     2032-12-01 2025-02-12
#
#   Application Date  Withdrawal Date  \
# 0        2024-11-22      2025-04-23
# 1        2024-11-15      2025-04-24
# 2        2024-11-18      2025-04-25
# 3        2024-11-18      2025-04-25
# 4        2024-11-18      2025-04-25
#
#                                         Service Type
# 0                              Energy Only Requested
# 1                              Energy Only Requested
# 2  Merchant- Full Capacity Deliverability Status ...
# 3  Merchant- Full Capacity Deliverability Status ...
# 4  Merchant- Full Capacity Deliverability Status ...
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Inspect Cluster 14

# %%
CLUSTER14_FILE = "PreliminaryCluster14ProjectListasofMay20-2021.xlsx"

path = RAW / CLUSTER14_FILE
inspect_excel(path)
# Out:
# **File:** `PreliminaryCluster14ProjectListasofMay20-2021.xlsx`
# **Sheets:** 2
#                          sheet
# 0                        Notes
# 1  C14 Prelim Cluster Overview
# #### Sheet: `Notes`
# Detected header row (0-based in preview): 0
# Columns: **1**
#                                               column
# 0  This information is provided as general inform...
# Preview: `head(5)`
#   This information is provided as general information of Interconnection Requests being processed in the ISO Generator Interconnection Queue for Cluster 14.
# 0                                                NaN
# 1  The information provided is based on informati...
# 2                                                NaN
# 3  The use of the information herein is solely at...
# #### Sheet: `C14 Prelim Cluster Overview`
# Detected header row (0-based in preview): 0
# Columns: **12**
#             column
# 0              PTO
# 1     Affected PTO
# 2             Area
# 3   Total MW @ POI
# 4   Technology\n#1
# 5            MW-T1
# 6   Technology\n#2
# 7            MW-T2
# 8   Technology\n#3
# 9            MW-T3
# 10             POI
# 11   Voltage\n(kV)
# Preview: `head(5)`
#     PTO Affected PTO     Area  Total MW @ POI Technology\n#1      MW-T1  \
# 0  DCRT          SCE  Eastern           500.0        Battery   516.7638
# 1  DCRT          SCE  Eastern           350.0        Battery   350.0000
# 2  DCRT          SCE  Eastern          2000.0        Battery  2000.0000
# 3  DCRT          SCE  Eastern           350.0       Solar PV   357.5300
# 4  DCRT          SCE  Eastern           700.0        Battery   718.8100
#
#   Technology\n#2     MW-T2 Technology\n#3  MW-T3                     POI  \
# 0       Solar PV  516.7638            NaN    NaN   Cielo Azul Substation
# 1       Solar PV  350.0000            NaN    NaN      Delaney Substation
# 2            NaN       NaN            NaN    NaN   Cielo Azul Substation
# 3            NaN       NaN            NaN    NaN  Delaney-Colorado River
# 4       Solar PV  718.8100            NaN    NaN  Delaney-Colorado River
#
#    Voltage\n(kV)
# 0          500.0
# 1          500.0
# 2          500.0
# 3          500.0
# 4          500.0
