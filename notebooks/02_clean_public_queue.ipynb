# %% [markdown]
# # Clean Public Queue Report

# %% [markdown]
# ### Imports

# %%
import sys
from pathlib import Path
import re

import pandas as pd
import numpy as np
from IPython.display import display, Markdown

# %% [markdown]
# ### Define Paths

# %%
CWD = Path.cwd()
ROOT = CWD.parent if CWD.name.lower() == "notebooks" else CWD

DATA = ROOT / "data"
RAW = DATA / "raw"
PROCESSED = DATA / "processed"

RAW.mkdir(parents=True, exist_ok=True)
PROCESSED.mkdir(parents=True, exist_ok=True)

print("Python:", sys.version.split()[0])
print("RAW:", RAW)
print("PROCESSED:", PROCESSED)
# Out:
# Python: 3.11.9
# RAW: C:\Users\danci\Interconnection-Queue-Intelligence\data\raw
# PROCESSED: C:\Users\danci\Interconnection-Queue-Intelligence\data\processed

# %% [markdown]
# ### Select Public Queue File

# %%
raw_files = sorted([p for p in RAW.iterdir() if p.is_file() and not p.name.startswith("~$")])

candidates = [p for p in raw_files if ("public" in p.name.lower() and "queue" in p.name.lower())]
public_path = candidates[0] if candidates else None

print("Detected:", public_path.name if public_path else None)
if public_path is None:
    raise FileNotFoundError("Could not find public queue file. Rename it to include 'public' and 'queue'.")
# Out:
# Detected: publicqueuereport.xlsx

# %% [markdown]
# ### Helpers

# %%
def normalize_cols(cols):
    """
    Normalize column names so mapping keys don't break on newlines/extra spaces.
    Also ensures uniqueness (duplicate names get .1, .2 suffixes).
    """
    norm = []
    for c in cols:
        s = "" if c is None else str(c)
        s = s.replace("\n", " ")
        s = re.sub(r"\s+", " ", s).strip()
        norm.append(s)

    # Ensure uniqueness to avoid pandas silently creating duplicate columns that break selections
    seen = {}
    out = []
    for s in norm:
        if s not in seen:
            seen[s] = 0
            out.append(s)
        else:
            seen[s] += 1
            out.append(f"{s}.{seen[s]}")
    return out


def clean_text(x):
    if pd.isna(x):
        return ""
    return str(x).strip()


def coerce_float(x):
    if pd.isna(x):
        return np.nan
    s = str(x).strip().replace(",", "")
    if s == "":
        return np.nan
    return pd.to_numeric(s, errors="coerce")


def parse_dt(series):
    # Works on either a Series or a scalar; returns Series if Series passed
    return pd.to_datetime(series, errors="coerce")


def normalize_tech(x):
    s = clean_text(x).lower()
    if s == "":
        return ""
    if any(k in s for k in ["battery", "storage", "bess"]):
        return "storage"
    if any(k in s for k in ["solar", "pv", "photovoltaic"]):
        return "solar"
    if "wind" in s:
        return "wind"
    return clean_text(x)


def looks_like_header_cell(x) -> bool:
    if x is None or (isinstance(x, float) and pd.isna(x)):
        return False
    s = str(x).strip()
    if s == "":
        return False
    # reject pure numbers
    if re.fullmatch(r"[-+]?\d+(\.\d+)?", s):
        return False
    # accept if any alpha char
    return bool(re.search(r"[A-Za-z]", s))


def detect_header_row(preview_df: pd.DataFrame, min_nonnull: int = 5) -> int:
    """
    Scores each row in a header=None preview.
    Picks row with many non-null, many header-ish strings, few duplicates.
    """
    best_i, best_score = 0, float("-inf")

    for i in range(len(preview_df)):
        row = preview_df.iloc[i]
        nonnull = row.dropna().tolist()

        if len(nonnull) < min_nonnull:
            continue

        headerish = sum(looks_like_header_cell(v) for v in nonnull)
        norm = [str(v).strip().lower() for v in nonnull]
        dup_penalty = len(norm) - len(set(norm))

        score = len(nonnull) + 2 * headerish - 1.5 * dup_penalty
        if score > best_score:
            best_score = score
            best_i = i

    return best_i


def read_sheet_with_detected_header(path, sheet_name, scan_rows=120):
    """
    1) Reads a preview with header=None
    2) Detects header row index
    3) Reads again using that header row
    4) Normalizes columns and drops 'Unnamed' columns safely (no index alignment issues)
    """
    preview = pd.read_excel(path, sheet_name=sheet_name, header=None, nrows=scan_rows)
    header_row = detect_header_row(preview)

    df = pd.read_excel(path, sheet_name=sheet_name, header=header_row)

    # normalize columns + drop unnamed (SAFE: uses list comprehension)
    df.columns = normalize_cols(df.columns)
    keep_cols = [c for c in df.columns if not str(c).startswith("Unnamed:")]
    df = df.loc[:, keep_cols].copy()

    return df, header_row

# %% [markdown]
# ### Load + Verify Sheets

# %%
SHEETS = [
    "Grid GenerationQueue",
    "Completed Generation Projects",
    "Withdrawn Generation Projects",
]

xls = pd.ExcelFile(public_path)
display(Markdown(f"**Workbook:** `{public_path.name}`"))
display(pd.DataFrame({"sheet_in_file": xls.sheet_names}))

missing = [s for s in SHEETS if s not in xls.sheet_names]
if missing:
    raise ValueError(f"Expected sheets not found: {missing}")
# Out:
# **Workbook:** `publicqueuereport.xlsx`
#                    sheet_in_file
# 0           Grid GenerationQueue
# 1  Completed Generation Projects
# 2  Withdrawn Generation Projects

# %% [markdown]
# ## Active Sheet

# %% [markdown]
# ### Load Active

# %%
active_raw, active_header_row = read_sheet_with_detected_header(public_path, SHEETS[0])
print("Detected header row:", active_header_row)
display(Markdown(f"**Shape:** {active_raw.shape}"))
display(active_raw.head(3))
display(pd.DataFrame({"column": active_raw.columns.tolist()}))
# Out:
# Detected header row: 3
# **Shape:** (335, 33)
#                  Project Name Queue Position  \
# 0  MONTEZUMA (HIGH WINDS III)             22
# 1                   TULE WIND             32
# 2              MIDWAY PEAKING             54
#
#   Interconnection Request Receive Date           Queue Date  \
# 0                  2003-11-18 00:00:00  2003-11-18 08:00:00
# 1                  2004-05-12 00:00:00  2004-05-24 07:00:00
# 2                  2005-01-12 00:00:00  2005-01-12 08:00:00
#
#   Application Status Study Process        Type-1   Type-2 Type-3  \
# 0             ACTIVE      AMEND 39  Wind Turbine  Storage    NaN
# 1             ACTIVE   Serial LGIP  Wind Turbine  Storage    NaN
# 2             ACTIVE   Serial LGIP   Gas Turbine  Storage    NaN
#
#          Fuel-1  ... PTO Study Region      Station or Transmission Line  \
# 0  Wind Turbine  ...         Northern              Birds Landing 230 kV
# 1  Wind Turbine  ...             SDGE  Boulevard East Substation 138 kV
# 2   Natural Gas  ...           Fresno                Panoche Substation
#
#    Proposed On-line Date (as filed with IR)  Current On-line Date  \
# 0                       2005-06-30 07:00:00   2024-04-01 07:00:00
# 1                       2007-09-01 07:00:00   2030-10-31 07:00:00
# 2                       2008-06-01 07:00:00   2027-06-30 07:00:00
#
#    Suspension Status  Feasibility Study or Supplemental Review  \
# 0                NaN                                       NaN
# 1                NaN                                    Waived
# 2                NaN                                    Waived
#
#   System Impact Study or Phase I Cluster Study  \
# 0                                     Complete
# 1                                     Complete
# 2                                     Complete
#
#    Facilities Study (FAS) or Phase II Cluster Study Optional Study (OS)  \
# 0                                          Complete                 NaN
# 1                                          Complete                 NaN
# 2                                          Re-Study                 NaN
#
#   Interconnection Agreement Status
# 0                         Executed
# 1                         Executed
# 2                         Executed
#
# [3 rows x 33 columns]
#                                               column
# 0                                       Project Name
# 1                                     Queue Position
# 2               Interconnection Request Receive Date
# 3                                         Queue Date
# 4                                 Application Status
# 5                                      Study Process
# 6                                             Type-1
# 7                                             Type-2
# 8                                             Type-3
# 9                                             Fuel-1
# 10                                            Fuel-2
# 11                                            Fuel-3
# 12                                              MW-1
# 13                                              MW-2
# 14                                              MW-3
# 15                                   Net MWs to Grid
# 16   Full Capacity, Partial or Energy Only (FC/P/EO)
# 17                         TPD Allocation Percentage
# 18         Off-Peak Deliverability and Economic Only
# 19                              TPD Allocation Group
# 20                                            County
# 21                                             State
# 22                                           Utility
# 23                                  PTO Study Region
# 24                      Station or Transmission Line
# 25          Proposed On-line Date (as filed with IR)
# 26                              Current On-line Date
# 27                                 Suspension Status
# 28          Feasibility Study or Supplemental Review
# 29      System Impact Study or Phase I Cluster Study
# 30  Facilities Study (FAS) or Phase II Cluster Study
# 31                               Optional Study (OS)
# 32                  Interconnection Agreement Status

# %% [markdown]
# ### Standardize Active

# %%
MAP_ACTIVE = {
    "Project Name": "project_name",
    "Queue Position": "queue_id",
    "Interconnection Request Receive Date": "date_received",
    "Queue Date": "date_queue",
    "Application Status": "status_raw",
    "Study Process": "study_process",
    "Fuel-1": "tech_1",
    "Fuel-2": "tech_2",
    "Fuel-3": "tech_3",
    "MW-1": "mw_1",
    "MW-2": "mw_2",
    "MW-3": "mw_3",
    "Net MWs to Grid": "mw_poi",
    "County": "county",
    "State": "state",
    "Utility": "pto",
    "PTO Study Region": "study_area",
    "Station or Transmission Line": "poi",
    "Proposed On-line Date (as filed with IR)": "date_cod_requested",
    "Current On-line Date": "date_cod_current_or_actual",
}

rename = {k: v for k, v in MAP_ACTIVE.items() if k in active_raw.columns}
active = active_raw.rename(columns=rename).copy()

active["source"] = "public_queue"
active["sheet_outcome"] = "active"

keep = [
    "source","sheet_outcome",
    "queue_id","project_name",
    "pto","study_area","poi",
    "county","state",
    "tech_1","mw_1","tech_2","mw_2","tech_3","mw_3",
    "mw_poi",
    "date_received","date_queue","date_cod_requested","date_cod_current_or_actual",
    "status_raw","study_process"
]
keep = [c for c in keep if c in active.columns]
active = active[keep].copy()

display(active.head(3))
# Out:
#          source sheet_outcome queue_id                project_name   pto  \
# 0  public_queue        active       22  MONTEZUMA (HIGH WINDS III)  PGAE
# 1  public_queue        active       32                   TULE WIND  SDGE
# 2  public_queue        active       54              MIDWAY PEAKING  PGAE
#
#   study_area                               poi     county state        tech_1  \
# 0   Northern              Birds Landing 230 kV     SOLANO    CA  Wind Turbine
# 1       SDGE  Boulevard East Substation 138 kV  SAN DIEGO    CA  Wind Turbine
# 2     Fresno                Panoche Substation     FRESNO    CA   Natural Gas
#
#    ...   mw_2 tech_3  mw_3 mw_poi        date_received           date_queue  \
# 0  ...   38.0    NaN   NaN   38.0  2003-11-18 00:00:00  2003-11-18 08:00:00
# 1  ...  131.6    NaN   NaN  193.8  2004-05-12 00:00:00  2004-05-24 07:00:00
# 2  ...  119.9    NaN   NaN  119.9  2005-01-12 00:00:00  2005-01-12 08:00:00
#
#    date_cod_requested date_cod_current_or_actual status_raw study_process
# 0 2005-06-30 07:00:00        2024-04-01 07:00:00     ACTIVE      AMEND 39
# 1 2007-09-01 07:00:00        2030-10-31 07:00:00     ACTIVE   Serial LGIP
# 2 2008-06-01 07:00:00        2027-06-30 07:00:00     ACTIVE   Serial LGIP
#
# [3 rows x 22 columns]

# %% [markdown]
# ### Clean Types Active

# %%
for c in ["queue_id","project_name","pto","study_area","poi","county","state","status_raw","study_process"]:
    if c in active.columns:
        active[c] = active[c].apply(clean_text)

for t in ["tech_1","tech_2","tech_3"]:
    if t in active.columns:
        active[t] = active[t].apply(normalize_tech)

for m in ["mw_1","mw_2","mw_3","mw_poi"]:
    if m in active.columns:
        active[m] = active[m].apply(coerce_float)

for d in ["date_received","date_queue","date_cod_requested","date_cod_current_or_actual"]:
    if d in active.columns:
        active[d] = parse_dt(active[d])

# mw_poi fallback if missing: sum of slots
if "mw_poi" not in active.columns:
    active["mw_poi"] = np.nan
if all(c in active.columns for c in ["mw_1","mw_2","mw_3"]):
    fallback = active[["mw_1","mw_2","mw_3"]].sum(axis=1, min_count=1)
    active["mw_poi"] = active["mw_poi"].where(active["mw_poi"].notna(), fallback)

display(active[["mw_poi","mw_1","mw_2","mw_3"]].head(5))
print("Active mw_poi missing share:", active["mw_poi"].isna().mean())
# Out:
#    mw_poi        mw_1   mw_2  mw_3
# 0   38.00   38.000000   38.0   NaN
# 1  193.80  127.600000  131.6   NaN
# 2  119.90  119.900000  119.9   NaN
# 3   73.27   73.269997   18.5   NaN
# 4  500.00  500.000000    NaN   NaN
# Active mw_poi missing share: 0.023880597014925373

# %% [markdown]
# ## Completed Sheet

# %% [markdown]
# ### Load Completed

# %%
completed_raw, completed_header_row = read_sheet_with_detected_header(public_path, SHEETS[1])
print("Detected header row:", completed_header_row)
display(Markdown(f"**Shape:** {completed_raw.shape}"))
display(completed_raw.head(3))
display(pd.DataFrame({"column": completed_raw.columns.tolist()}))
# Out:
# Detected header row: 3
# **Shape:** (237, 32)
#                                         Project Name Queue Position  \
# 0                       OTAY MESA GENERATING PROJECT             1A
# 1  GATEWAY GENERATING FACILITY (FKA CONTRA COSTA ...              2
# 2               CPV SENTINEL (FKA INTERGEN OCOTILLO)              3
#
#   Interconnection Request Receive Date          Queue Date Application Status  \
# 0                           1999-11-01 1999-11-01 08:00:00          COMPLETED
# 1                           1999-08-10 2000-02-03 08:00:00          COMPLETED
# 2                           2000-04-21 2000-06-14 07:00:00          COMPLETED
#
#     Study Process          Type-1   Type-2  Type-3       Fuel-1  ... Utility  \
# 0  Pre- Amend. 39  Combined Cycle      NaN     NaN  Natural Gas  ...    SDGE
# 1  Pre- Amend. 39  Combined Cycle      NaN     NaN  Natural Gas  ...    PGAE
# 2     Serial LGIP     Gas Turbine  Storage     NaN  Natural Gas  ...     SCE
#
#    PTO Study Region         Station or Transmission Line  \
# 0               NaN          Otay Mesa Switchyard 230 kV
# 1               NaN  Contra Costa Power Plant 230 kV bus
# 2           Eastern          Devers Substation 230kV Bus
#
#    Proposed On-line Date (as filed with IR)  Actual On-line Date  \
# 0                       2002-03-01 08:00:00  2009-10-02 07:00:00
# 1                       2007-11-28 08:00:00  2009-01-06 08:00:00
# 2                       2004-01-01 08:00:00  2013-06-01 07:00:00
#
#    Feasibility Study or Supplemental Review  \
# 0                                       NaN
# 1                                       NaN
# 2                                    Waived
#
#   System Impact Study or Phase I Cluster Study  \
# 0                                     Complete
# 1                                     Complete
# 2                                     Re-Study
#
#    Facilities Study (FAS) or Phase II Cluster Study Optional Study (OS)  \
# 0                                          Complete                 NaN
# 1                                          Complete                 NaN
# 2                                          Re-Study            Complete
#
#   Interconnection Agreement Status
# 0                         Executed
# 1                         Executed
# 2                         Executed
#
# [3 rows x 32 columns]
#                                               column
# 0                                       Project Name
# 1                                     Queue Position
# 2               Interconnection Request Receive Date
# 3                                         Queue Date
# 4                                 Application Status
# 5                                      Study Process
# 6                                             Type-1
# 7                                             Type-2
# 8                                             Type-3
# 9                                             Fuel-1
# 10                                            Fuel-2
# 11                                            Fuel-3
# 12                                              MW-1
# 13                                              MW-2
# 14                                              MW-3
# 15                                   Net MWs to Grid
# 16   Full Capacity, Partial or Energy Only (FC/P/EO)
# 17                         TPD Allocation Percentage
# 18         Off-Peak Deliverability and Economic Only
# 19                              TPD Allocation Group
# 20                                            County
# 21                                             State
# 22                                           Utility
# 23                                  PTO Study Region
# 24                      Station or Transmission Line
# 25          Proposed On-line Date (as filed with IR)
# 26                               Actual On-line Date
# 27          Feasibility Study or Supplemental Review
# 28      System Impact Study or Phase I Cluster Study
# 29  Facilities Study (FAS) or Phase II Cluster Study
# 30                               Optional Study (OS)
# 31                  Interconnection Agreement Status

# %% [markdown]
# ### Standardize Completed

# %%
MAP_COMPLETED = {
    "Project Name": "project_name",
    "Queue Position": "queue_id",
    "Interconnection Request Receive Date": "date_received",
    "Queue Date": "date_queue",
    "Application Status": "status_raw",
    "Study Process": "study_process",
    "Fuel-1": "tech_1",
    "Fuel-2": "tech_2",
    "Fuel-3": "tech_3",
    "MW-1": "mw_1",
    "MW-2": "mw_2",
    "MW-3": "mw_3",
    "Net MWs to Grid": "mw_poi",
    "County": "county",
    "State": "state",
    "Utility": "pto",
    "PTO Study Region": "study_area",
    "Station or Transmission Line": "poi",
    "Proposed On-line Date (as filed with IR)": "date_cod_requested",
    "Actual On-line Date": "date_cod_current_or_actual",
}

rename = {k: v for k, v in MAP_COMPLETED.items() if k in completed_raw.columns}
completed = completed_raw.rename(columns=rename).copy()

completed["source"] = "public_queue"
completed["sheet_outcome"] = "completed"

keep = [
    "source","sheet_outcome",
    "queue_id","project_name",
    "pto","study_area","poi",
    "county","state",
    "tech_1","mw_1","tech_2","mw_2","tech_3","mw_3",
    "mw_poi",
    "date_received","date_queue","date_cod_requested","date_cod_current_or_actual",
    "status_raw","study_process"
]
keep = [c for c in keep if c in completed.columns]
completed = completed[keep].copy()

display(completed.head(3))
# Out:
#          source sheet_outcome queue_id  \
# 0  public_queue     completed       1A
# 1  public_queue     completed        2
# 2  public_queue     completed        3
#
#                                         project_name   pto study_area  \
# 0                       OTAY MESA GENERATING PROJECT  SDGE        NaN
# 1  GATEWAY GENERATING FACILITY (FKA CONTRA COSTA ...  PGAE        NaN
# 2               CPV SENTINEL (FKA INTERGEN OCOTILLO)   SCE    Eastern
#
#                                    poi        county state       tech_1  ...  \
# 0          Otay Mesa Switchyard 230 kV     SAN DIEGO    CA  Natural Gas  ...
# 1  Contra Costa Power Plant 230 kV bus  CONTRA COSTA    CA  Natural Gas  ...
# 2          Devers Substation 230kV Bus     RIVERSIDE    CA  Natural Gas  ...
#
#    mw_2 tech_3  mw_3  mw_poi  date_received          date_queue  \
# 0   NaN    NaN   NaN   550.0     1999-11-01 1999-11-01 08:00:00
# 1   NaN    NaN   NaN   590.0     1999-08-10 2000-02-03 08:00:00
# 2  16.0    NaN   NaN   850.0     2000-04-21 2000-06-14 07:00:00
#
#    date_cod_requested date_cod_current_or_actual status_raw   study_process
# 0 2002-03-01 08:00:00        2009-10-02 07:00:00  COMPLETED  Pre- Amend. 39
# 1 2007-11-28 08:00:00        2009-01-06 08:00:00  COMPLETED  Pre- Amend. 39
# 2 2004-01-01 08:00:00        2013-06-01 07:00:00  COMPLETED     Serial LGIP
#
# [3 rows x 22 columns]

# %% [markdown]
# ### Clean Types Completed

# %%
for c in ["queue_id","project_name","pto","study_area","poi","county","state","status_raw","study_process"]:
    if c in completed.columns:
        completed[c] = completed[c].apply(clean_text)

for t in ["tech_1","tech_2","tech_3"]:
    if t in completed.columns:
        completed[t] = completed[t].apply(normalize_tech)

for m in ["mw_1","mw_2","mw_3","mw_poi"]:
    if m in completed.columns:
        completed[m] = completed[m].apply(coerce_float)

for d in ["date_received","date_queue","date_cod_requested","date_cod_current_or_actual"]:
    if d in completed.columns:
        completed[d] = parse_dt(completed[d])

if "mw_poi" not in completed.columns:
    completed["mw_poi"] = np.nan
if all(c in completed.columns for c in ["mw_1","mw_2","mw_3"]):
    fallback = completed[["mw_1","mw_2","mw_3"]].sum(axis=1, min_count=1)
    completed["mw_poi"] = completed["mw_poi"].where(completed["mw_poi"].notna(), fallback)

display(completed[["mw_poi","mw_1","mw_2","mw_3"]].head(5))
print("Completed mw_poi missing share:", completed["mw_poi"].isna().mean())
# Out:
#    mw_poi   mw_1  mw_2  mw_3
# 0   550.0  550.0   NaN   NaN
# 1   590.0  590.0   NaN   NaN
# 2   850.0  850.0  16.0   NaN
# 3   521.0  521.0   NaN   NaN
# 4   570.0  570.0   NaN   NaN
# Completed mw_poi missing share: 0.008438818565400843

# %% [markdown]
# ## Withdrawn Sheet

# %% [markdown]
# ### Load Withdrawn

# %%
withdrawn_raw, withdrawn_header_row = read_sheet_with_detected_header(public_path, SHEETS[2])
print("Detected header row:", withdrawn_header_row)
display(Markdown(f"**Shape:** {withdrawn_raw.shape}"))
display(withdrawn_raw.head(3))
display(pd.DataFrame({"column": withdrawn_raw.columns.tolist()}))
# Out:
# Detected header row: 3
# **Shape:** (1718, 31)
#                     Project Name - Confidential Queue Position  \
# 0       ENCINA GENERATING PROJECT (PH. 1 AND 2)              5
# 1                             TESLA POWER PLANT              6
# 2  SAN DIEGO COMMUNITY POWER GENERATING STATION              8
#
#   Interconnection Request Receive Date          Queue Date Application Status  \
# 0                           2000-08-09 2000-08-09 07:00:00          WITHDRAWN
# 1                           2007-08-24 2000-08-23 07:00:00          WITHDRAWN
# 2                           2000-11-28 2000-11-28 08:00:00          WITHDRAWN
#
#        Withdrawn Date   Study Process          Type-1 Type-2 Type-3  ...  \
# 0                 NaT  Pre- Amend. 39  Combined Cycle    NaN    NaN  ...
# 1 2011-06-16 17:56:36     Serial LGIP  Combined Cycle    NaN    NaN  ...
# 2                 NaT  Pre- Amend. 39  Combined Cycle    NaN    NaN  ...
#
#   Utility   Station or Transmission Line  \
# 0    SDGE  Encina Power Plant Switchyard
# 1    PGAE          Tesla Sub 230kV Bus E
# 2    SDGE     Sycamore Canyon Substation
#
#   Proposed On-line Date (as filed with IR)  Current On-line Date  \
# 0                      2003-06-30 07:00:00   2008-06-01 07:00:00
# 1                      2008-06-01 07:00:00   2014-11-30 08:00:00
# 2                      2004-06-01 07:00:00   2010-12-31 08:00:00
#
#    Feasibility Study or Supplemental Review  \
# 0                                       NaN
# 1                                    Waived
# 2                                       NaN
#
#    System Impact Study or Phase I Cluster Study  \
# 0                                      Complete
# 1                                      Complete
# 2                                      Complete
#
#    Facilities Study (FAS) or Phase II Cluster Study Optional Study (OS)  \
# 0                                               NaN                 NaN
# 1                                          Complete            Complete
# 2                                          Re-Study                 NaN
#
#   Interconnection Agreement Status Reason for Withdrawal
# 0                              NaN                   NaN
# 1                              NaN                   NaN
# 2                      In Progress                   NaN
#
# [3 rows x 31 columns]
#                                               column
# 0                        Project Name - Confidential
# 1                                     Queue Position
# 2               Interconnection Request Receive Date
# 3                                         Queue Date
# 4                                 Application Status
# 5                                     Withdrawn Date
# 6                                      Study Process
# 7                                             Type-1
# 8                                             Type-2
# 9                                             Type-3
# 10                                            Fuel-1
# 11                                            Fuel-2
# 12                                            Fuel-3
# 13                                              MW-1
# 14                                              MW-2
# 15                                              MW-3
# 16                                   Net MWs to Grid
# 17   Full Capacity, Partial or Energy Only (FC/P/EO)
# 18         Off-Peak Deliverability and Economic Only
# 19                                            County
# 20                                             State
# 21                                           Utility
# 22                      Station or Transmission Line
# 23          Proposed On-line Date (as filed with IR)
# 24                              Current On-line Date
# 25          Feasibility Study or Supplemental Review
# 26      System Impact Study or Phase I Cluster Study
# 27  Facilities Study (FAS) or Phase II Cluster Study
# 28                               Optional Study (OS)
# 29                  Interconnection Agreement Status
# 30                             Reason for Withdrawal

# %% [markdown]
# ### Standardize Withdrawn

# %%
MAP_WITHDRAWN = {
    "Project Name - Confidential": "project_name",
    "Project Name": "project_name",
    "Queue Position": "queue_id",
    "Interconnection Request Receive Date": "date_received",
    "Queue Date": "date_queue",
    "Withdrawn Date": "date_withdrawn",
    "Application Status": "status_raw",
    "Study Process": "study_process",
    "Fuel-1": "tech_1",
    "Fuel-2": "tech_2",
    "Fuel-3": "tech_3",
    "MW-1": "mw_1",
    "MW-2": "mw_2",
    "MW-3": "mw_3",
    "Net MWs to Grid": "mw_poi",
    "County": "county",
    "State": "state",
    "Utility": "pto",
    "PTO Study Region": "study_area",  # may be absent in withdrawn
    "Station or Transmission Line": "poi",
    "Proposed On-line Date (as filed with IR)": "date_cod_requested",
    "Current On-line Date": "date_cod_current_or_actual",
    "Reason for Withdrawal": "withdraw_reason",
}

rename = {k: v for k, v in MAP_WITHDRAWN.items() if k in withdrawn_raw.columns}
withdrawn = withdrawn_raw.rename(columns=rename).copy()

withdrawn["source"] = "public_queue"
withdrawn["sheet_outcome"] = "withdrawn"

keep = [
    "source","sheet_outcome",
    "queue_id","project_name",
    "pto","study_area","poi",
    "county","state",
    "tech_1","mw_1","tech_2","mw_2","tech_3","mw_3",
    "mw_poi",
    "date_received","date_queue","date_cod_requested","date_cod_current_or_actual","date_withdrawn",
    "status_raw","study_process","withdraw_reason"
]
keep = [c for c in keep if c in withdrawn.columns]
withdrawn = withdrawn[keep].copy()

display(withdrawn.head(3))
# Out:
#          source sheet_outcome queue_id  \
# 0  public_queue     withdrawn        5
# 1  public_queue     withdrawn        6
# 2  public_queue     withdrawn        8
#
#                                    project_name   pto  \
# 0       ENCINA GENERATING PROJECT (PH. 1 AND 2)  SDGE
# 1                             TESLA POWER PLANT  PGAE
# 2  SAN DIEGO COMMUNITY POWER GENERATING STATION  SDGE
#
#                              poi       county state       tech_1    mw_1  ...  \
# 0  Encina Power Plant Switchyard    SAN DIEGO    CA  Natural Gas   900.0  ...
# 1          Tesla Sub 230kV Bus E  SAN JOAQUIN    CA  Natural Gas  1156.0  ...
# 2     Sycamore Canyon Substation    SAN DIEGO    CA  Natural Gas   750.0  ...
#
#   mw_3  mw_poi date_received          date_queue  date_cod_requested  \
# 0  NaN   900.0    2000-08-09 2000-08-09 07:00:00 2003-06-30 07:00:00
# 1  NaN  1156.0    2007-08-24 2000-08-23 07:00:00 2008-06-01 07:00:00
# 2  NaN   750.0    2000-11-28 2000-11-28 08:00:00 2004-06-01 07:00:00
#
#   date_cod_current_or_actual      date_withdrawn status_raw   study_process  \
# 0        2008-06-01 07:00:00                 NaT  WITHDRAWN  Pre- Amend. 39
# 1        2014-11-30 08:00:00 2011-06-16 17:56:36  WITHDRAWN     Serial LGIP
# 2        2010-12-31 08:00:00                 NaT  WITHDRAWN  Pre- Amend. 39
#
#   withdraw_reason
# 0             NaN
# 1             NaN
# 2             NaN
#
# [3 rows x 23 columns]

# %% [markdown]
# ### Clean Types Withdrawn

# %%
for c in ["queue_id","project_name","pto","study_area","poi","county","state","status_raw","study_process","withdraw_reason"]:
    if c in withdrawn.columns:
        withdrawn[c] = withdrawn[c].apply(clean_text)

for t in ["tech_1","tech_2","tech_3"]:
    if t in withdrawn.columns:
        withdrawn[t] = withdrawn[t].apply(normalize_tech)

for m in ["mw_1","mw_2","mw_3","mw_poi"]:
    if m in withdrawn.columns:
        withdrawn[m] = withdrawn[m].apply(coerce_float)

for d in ["date_received","date_queue","date_cod_requested","date_cod_current_or_actual","date_withdrawn"]:
    if d in withdrawn.columns:
        withdrawn[d] = parse_dt(withdrawn[d])

if "mw_poi" not in withdrawn.columns:
    withdrawn["mw_poi"] = np.nan
if all(c in withdrawn.columns for c in ["mw_1","mw_2","mw_3"]):
    fallback = withdrawn[["mw_1","mw_2","mw_3"]].sum(axis=1, min_count=1)
    withdrawn["mw_poi"] = withdrawn["mw_poi"].where(withdrawn["mw_poi"].notna(), fallback)

display(withdrawn[["mw_poi","mw_1","mw_2","mw_3"]].head(5))
print("Withdrawn mw_poi missing share:", withdrawn["mw_poi"].isna().mean())
# Out:
#    mw_poi    mw_1  mw_2  mw_3
# 0   900.0   900.0   NaN   NaN
# 1  1156.0  1156.0   NaN   NaN
# 2   750.0   750.0   NaN   NaN
# 3  1200.0  1200.0   NaN   NaN
# 4   620.0   620.0   NaN   NaN
# Withdrawn mw_poi missing share: 0.0011641443538998836

# %% [markdown]
# ## Combine & Save

# %%
public_all = pd.concat([active, completed, withdrawn], ignore_index=True)

display(Markdown("**Combined shape:**"))
display(pd.DataFrame({
    "part": ["active","completed","withdrawn","ALL"],
    "rows": [len(active), len(completed), len(withdrawn), len(public_all)]
}))
display(public_all.head(50))
# Out:
# **Combined shape:**
#         part  rows
# 0     active   335
# 1  completed   237
# 2  withdrawn  1718
# 3        ALL  2290
#           source sheet_outcome queue_id  \
# 0   public_queue        active       22
# 1   public_queue        active       32
# 2   public_queue        active       54
# 3   public_queue        active       61
# 4   public_queue        active       72
# 5   public_queue        active       81
# 6   public_queue        active       96
# 7   public_queue        active      100
# 8   public_queue        active      124
# 9   public_queue        active      138
# 10  public_queue        active      222
# 11  public_queue        active      268
# 12  public_queue        active      272
# 13  public_queue        active      297
# 14  public_queue        active      378
# 15  public_queue        active      493
# 16  public_queue        active      506
# 17  public_queue        active      539
# 18  public_queue        active      625
# 19  public_queue        active     643R
# 20  public_queue        active     653B
# 21  public_queue        active      678
# 22  public_queue        active      720
# 23  public_queue        active      744
# 24  public_queue        active      768
# 25  public_queue        active      779
# 26  public_queue        active      900
# 27  public_queue        active      972
# 28  public_queue        active      993
# 29  public_queue        active     1002
# 30  public_queue        active     1028
# 31  public_queue        active     1029
# 32  public_queue        active     1045
# 33  public_queue        active     1047
# 34  public_queue        active     1048
# 35  public_queue        active     1062
# 36  public_queue        active     1064
# 37  public_queue        active     1074
# 38  public_queue        active     1076
# 39  public_queue        active     1096
# 40  public_queue        active     1106
# 41  public_queue        active     1127
# 42  public_queue        active     1128
# 43  public_queue        active     1129
# 44  public_queue        active     1135
# 45  public_queue        active     1143
# 46  public_queue        active     1166
# 47  public_queue        active     1169
# 48  public_queue        active     1175
# 49  public_queue        active     1204
#
#                                          project_name   pto study_area  \
# 0                          MONTEZUMA (HIGH WINDS III)  PGAE   Northern
# 1                                           TULE WIND  SDGE       SDGE
# 2                                      MIDWAY PEAKING  PGAE     Fresno
# 3               FRESNO COGENERATION EXPANSION PROJECT  PGAE     Fresno
# 4       LAKE ELSINORE ADVANCED PUMPED STORAGE PROJECT  SDGE       SDGE
# 5                                   BOTTLE ROCK POWER  PGAE       Kern
# 6                                            CPC WEST   SCE   Northern
# 7                                WINDSTAR I ALTERNATE   SCE   Northern
# 8                           SILVER RIDGE MOUNT SIGNAL  SDGE
# 9                                SANDSTORM WIND POWER   SCE    Eastern
# 10                                       MONTEZUMA II  PGAE   Northern
# 11                   TRACY COMBINED-CYCLE POWER PLANT  PGAE
# 12                               AMERICAN KINGS SOLAR  PGAE     Fresno
# 13             ALTA VISTA SUNTOWER GENERATING STATION   SCE   Northern
# 14     LOS ESTEROS CRITICAL ENERGY FACILITY EXPANSION  PGAE   Northern
# 15                                   OCOTILLO EXPRESS  SDGE
# 16                                ROSAMOND WEST SOLAR   SCE   Northern
# 17  CROW CREEK SOLAR 1 (FKA: FRONTIER SOLAR 1) (FK...  PGAE
# 18  KETTLEMAN SOLAR PROJECT (FKA KETTLEMAN SOLAR F...  PGAE     Fresno
# 19                               NORTH ROSAMOND SOLAR   SCE   Northern
# 20             PUMPJACK SOLAR I (AKA PIONEER SOLAR I)  PGAE
# 21         EXCELSIOR SOLAR (FKA: BURFORD FIVE POINTS)  PGAE     Fresno
# 22                         LASSEN LODGE HYDROELECTRIC  PGAE   Northern
# 23                                 REDWOOD SOLAR FARM  PGAE       Kern
# 24                                      BIG SKY SOLAR   SCE   Northern
# 25                                       WRIGHT SOLAR  PGAE     Fresno
# 26                                  RIO BRAVO SOLAR 1  PGAE
# 27                                  RIO BRAVO SOLAR 2  PGAE
# 28                            SUNSHINE VALLEY SOLAR 1   VEA        EOP
# 29                       LASSEN LODGE HYDROELECTRIC 2  PGAE   Northern
# 30                                LITTLE BEAR SOLAR 1  PGAE
# 31                                LITTLE BEAR SOLAR 2  PGAE
# 32                        CHULA VISTA ENERGY CENTER 2  SDGE       SDGE
# 33                        NORTH JOHNSON ENERGY CENTER  SDGE       SDGE
# 34                          ESCONDIDO ENERGY CENTER 2  SDGE       SDGE
# 35                             WHITE WING RANCH SOLAR  SDGE       SDGE
# 36                                        ARES NEVADA   GLW
# 37                                       GASKELL WEST   SCE   Northern
# 38                             WILLOW SPRINGS SOLAR 3   SCE   Northern
# 39                                ALTAMONT MIDWAY LTD  PGAE   Northern
# 40                                      FOUNTAIN WIND  PGAE   Northern
# 41                                      LITTLE BEAR 3  PGAE
# 42                                      LITTLE BEAR 4  PGAE     Fresno
# 43                                  LUNA VALLEY SOLAR  PGAE     Fresno
# 44                                            SCARLET  PGAE     Fresno
# 45                       LAKE ALPAUGH BATTERY STORAGE  PGAE       Kern
# 46                                BIG ROCK SOLAR FARM  SDGE       SDGE
# 47                           FALLBROOK ENERGY STORAGE  SDGE       SDGE
# 48                             LECONTE ENERGY STORAGE  SDGE       SDGE
# 49                             ARATINA SOLAR CENTER 1   SCE        NOL
#
#                                                 poi          county state  \
# 0                              Birds Landing 230 kV          SOLANO    CA
# 1                  Boulevard East Substation 138 kV       SAN DIEGO    CA
# 2                                Panoche Substation          FRESNO    CA
# 3                            Helm-Kerman 70 kV Line          FRESNO    CA
# 4               Proposed Lee Lake Substation 500 kV       RIVERSIDE    CA
# 5                    Geysers #17-Fulton 230 kV Line            LAKE    CA
# 6                Tehachapi Conceptual Substation #1            KERN    CA
# 7                          Vincent Substation 230kV            KERN    CA
# 8                 Imperial Valley Substation 230 kV        IMPERIAL    CA
# 9                          Devers Substation 220 kV       RIVERSIDE    CA
# 10                             Birds Landing 230 kV          SOLANO    CA
# 11  Tesla-Manteca 115kV line via Schulte Switchyard     SAN JOAQUIN    CA
# 12                                  Henrietta 70 kV           KINGS    CA
# 13                         Neenach-Bailey 66kV line     LOS ANGELES    CA
# 14                               Los Esteros 115 kV     SANTA CLARA    CA
# 15                       Ocotillo Switchyard 500 kV        IMPERIAL    CA
# 16                       Whirlwind Substation 230kV            KERN    CA
# 17                       Salado-Newman #1 60kV Line      STANISLAUS    CA
# 18                      Henrietta-Tulare Lake 70 kV           KINGS    CA
# 19                         Whirlwind Sub 230 kV Bus            KERN    CA
# 20                        Belridge - Temblor 115 kV            KERN    CA
# 21          Panoche-Schindler #1 and #2 115 kV Line          FRESNO    CA
# 22                                 Vota-South 60 kV          TEHAMA    CA
# 23                                    Lamont 115 KV            KERN    CA
# 24                    Antelope Substation 230kV bus     LOS ANGELES    CA
# 25                  Los Banos-Panoche #1 230kV Line          MERCED    CA
# 26                       Midway Temblor 115 kV line            KERN    CA
# 27                        Midway-Temblor 115kV line            KERN    CA
# 28                         Valley Substation 138 kV             NYE    NV
# 29                           Volta-South 60 kV Line          TEHAMA    CA
# 30                        Mendota Substation 115 kV          FRESNO    CA
# 31                        Mendota Substation 115 kV          FRESNO    CA
# 32                            Otay Substation 69 kV       SAN DIEGO    CA
# 33                        El Cajon Substation 69 kV       SAN DIEGO    CA
# 34                       Escondido Substation 69 kV       SAN DIEGO    CA
# 35                    Hoodoo Wash Switchyard 500 kV            YUMA    AZ
# 36                       Gamebird Substation 230 kV             NYE    NV
# 37                      Whirlwind Substation 220 kV            KERN    CA
# 38                      Whirlwind Substation 230 kV            KERN    CA
# 39                           Altamont Midway 230 kV         ALAMEDA    CA
# 40                     Pit 1-Cottonwood 230 kV Line          SHASTA    CA
# 41                         Mendota Substation 115kV          FRESNO    CA
# 42                         Mendota Substation 115kV          FRESNO    CA
# 43                               Tranquility 230 kV          FRESNO    CA
# 44                               Tranquility 230 kV          FRESNO    CA
# 45                       Corcoran-Olive 115 kV Line          TULARE    CA
# 46                Imperial Valley Substation 230 kV        IMPERIAL    CA
# 47                         Avocado Substation 69 kV       SAN DIEGO    CA
# 48                Imperial Valley Substation 230 kV        IMPERIAL    CA
# 49                          Kramer Substation 230kV  SAN BERNARDINO    CA
#
#               tech_1  ...   mw_3  mw_poi  date_received          date_queue  \
# 0               wind  ...    NaN   38.00     2003-11-18 2003-11-18 08:00:00
# 1               wind  ...    NaN  193.80     2004-05-12 2004-05-24 07:00:00
# 2        Natural Gas  ...    NaN  119.90     2005-01-12 2005-01-12 08:00:00
# 3        Natural Gas  ...    NaN   73.27     2005-03-28 2005-03-30 08:00:00
# 4            storage  ...    NaN  500.00     2005-04-26 2005-06-21 07:00:00
# 5         Geothermal  ...    NaN   52.01     2005-09-13 2005-09-13 07:00:00
# 6               wind  ...  150.0  600.00     2006-02-15 2006-03-01 08:00:00
# 7               wind  ...    NaN  120.00     2006-04-05 2006-04-05 07:00:00
# 8              solar  ...    NaN  600.00     2006-08-22 2006-08-22 07:00:00
# 9               wind  ...    NaN  150.00     2006-10-23 2006-10-23 07:00:00
# 10              wind  ...    NaN   78.00     2007-05-23 2007-05-23 07:00:00
# 11       Natural Gas  ...    NaN  145.00     2007-10-24 2007-10-24 07:00:00
# 12             solar  ...    NaN  123.00     2007-11-01 2007-11-01 07:00:00
# 13             solar  ...    NaN   66.00     2008-01-18 2008-01-18 08:00:00
# 14       Natural Gas  ...    NaN  120.00     2008-05-28 2008-05-28 07:00:00
# 15              wind  ...    NaN  265.44     2009-07-16 2009-07-31 07:00:00
# 16             solar  ...    NaN  299.60     2009-07-30 2009-07-31 07:00:00
# 17             solar  ...    NaN   20.00     2009-12-18 2009-12-18 08:00:00
# 18             solar  ...    NaN   20.00     2010-05-14 2010-05-14 07:00:00
# 19             solar  ...    NaN  153.00     2010-07-30 2010-07-31 07:00:00
# 20             solar  ...    NaN   20.00     2010-09-29 2010-09-29 07:00:00
# 21             solar  ...    NaN   60.00     2011-03-31 2011-03-31 07:00:00
# 22             Water  ...    NaN    4.50     2011-03-31 2011-03-31 07:00:00
# 23             solar  ...    NaN   90.00     2011-03-31 2011-03-31 07:00:00
# 24             solar  ...    NaN  320.00     2011-03-31 2011-03-31 07:00:00
# 25             solar  ...    NaN  200.00     2011-03-31 2011-03-31 07:00:00
# 26             solar  ...    NaN   20.00     2012-04-02 2012-04-02 07:00:00
# 27             solar  ...    NaN   20.00     2013-04-30 2013-04-30 07:00:00
# 28             solar  ...    NaN   50.00     2013-04-30 2013-04-30 07:00:00
# 29             Water  ...    NaN    0.50     2013-05-01 2013-04-30 07:00:00
# 30             solar  ...    NaN   20.00     2014-04-30 2014-04-30 07:00:00
# 31             solar  ...    NaN   20.00     2014-04-30 2014-04-30 07:00:00
# 32           storage  ...    NaN   50.00     2014-04-30 2014-04-30 07:00:00
# 33           storage  ...    NaN   50.00     2014-04-30 2014-04-30 07:00:00
# 34           storage  ...    NaN   33.00     2014-04-30 2014-04-30 07:00:00
# 35             solar  ...    NaN  200.00     2014-04-30 2014-04-30 07:00:00
# 36  Gravity via Rail  ...    NaN   44.00     2014-04-30 2014-04-30 07:00:00
# 37             solar  ...    NaN  125.00     2014-04-30 2014-04-30 07:00:00
# 38           storage  ...    NaN   50.00     2014-04-30 2014-04-30 07:00:00
# 39              wind  ...    NaN    5.00     2015-02-24 2015-04-13 07:00:00
# 40              wind  ...    NaN  200.00     2015-04-30 2015-04-30 07:00:00
# 41             solar  ...    NaN   20.00     2015-04-28 2015-04-30 07:00:00
# 42             solar  ...    NaN  100.00     2015-04-28 2015-04-30 07:00:00
# 43             solar  ...    NaN  200.00     2015-04-30 2015-04-30 07:00:00
# 44             solar  ...    NaN  400.00     2015-04-29 2015-04-30 07:00:00
# 45           storage  ...    NaN   10.00     2015-04-29 2015-04-30 07:00:00
# 46           storage  ...    NaN  200.00     2015-04-30 2015-04-30 07:00:00
# 47           storage  ...    NaN   69.60     2015-04-30 2015-04-30 07:00:00
# 48           storage  ...    NaN  125.00     2015-04-29 2015-04-30 07:00:00
# 49             solar  ...    NaN  200.00     2015-04-30 2015-04-30 07:00:00
#
#     date_cod_requested  date_cod_current_or_actual status_raw study_process  \
# 0  2005-06-30 07:00:00         2024-04-01 07:00:00     ACTIVE      AMEND 39
# 1  2007-09-01 07:00:00         2030-10-31 07:00:00     ACTIVE   Serial LGIP
# 2  2008-06-01 07:00:00         2027-06-30 07:00:00     ACTIVE   Serial LGIP
# 3  2006-05-31 07:00:00         2023-02-28 08:00:00     ACTIVE      AMEND 39
# 4  2008-12-31 08:00:00         2028-12-31 08:00:00     ACTIVE   Serial LGIP
# 5  2006-09-01 07:00:00         2027-11-30 08:00:00     ACTIVE   Serial LGIP
# 6  2009-12-31 08:00:00         2025-06-05 07:00:00     ACTIVE   Serial LGIP
# 7  2007-12-31 08:00:00         2030-10-15 07:00:00     ACTIVE   Serial LGIP
# 8  2011-03-01 08:00:00         2027-06-01 07:00:00     ACTIVE   Serial LGIP
# 9  2008-12-31 08:00:00         2030-02-01 08:00:00     ACTIVE   Serial LGIP
# 10 2010-12-31 08:00:00         2012-01-29 08:00:00     ACTIVE            TC
# 11 2012-06-01 07:00:00         2027-04-28 07:00:00     ACTIVE   Serial LGIP
# 12 2012-06-01 07:00:00         2025-12-30 08:00:00     ACTIVE            TC
# 13 2009-12-01 08:00:00         2027-12-11 08:00:00     ACTIVE            TC
# 14 2011-06-01 07:00:00         2023-09-01 07:00:00     ACTIVE            TC
# 15 2013-12-31 08:00:00         2030-05-31 07:00:00     ACTIVE           C01
# 16 2015-07-31 07:00:00         2029-03-31 07:00:00     ACTIVE           C01
# 17 2012-10-31 07:00:00         2025-04-01 07:00:00     ACTIVE          SGIP
# 18 2011-12-31 08:00:00         2025-04-01 07:00:00     ACTIVE          SGIP
# 19 2013-06-01 07:00:00         2026-06-01 07:00:00     ACTIVE           C03
# 20 2013-05-01 07:00:00         2027-06-01 07:00:00     ACTIVE       SGIP-TC
# 21 2013-09-05 07:00:00         2024-12-20 08:00:00     ACTIVE           C04
# 22 2012-12-15 08:00:00         2027-10-15 07:00:00     ACTIVE           C04
# 23 2014-07-01 07:00:00         2024-07-01 07:00:00     ACTIVE           C04
# 24 2014-12-31 08:00:00         2023-01-31 08:00:00     ACTIVE           C04
# 25 2014-01-06 08:00:00         2026-03-30 07:00:00     ACTIVE           C04
# 26 2014-12-20 08:00:00         2027-06-30 07:00:00     ACTIVE           C05
# 27 2016-12-31 08:00:00         2027-07-30 07:00:00     ACTIVE           C06
# 28 2016-12-31 08:00:00         2026-12-31 08:00:00     ACTIVE           C06
# 29 2015-11-15 08:00:00         2027-10-15 07:00:00     ACTIVE           C06
# 30 2016-12-01 08:00:00         2029-02-01 08:00:00     ACTIVE           C07
# 31 2018-09-01 07:00:00         2029-02-01 08:00:00     ACTIVE           C07
# 32 2019-11-01 07:00:00         2026-04-28 07:00:00     ACTIVE           C07
# 33 2019-11-01 07:00:00         2026-04-01 07:00:00     ACTIVE           C07
# 34 2019-11-01 07:00:00         2030-06-01 07:00:00     ACTIVE           C07
# 35 2018-12-31 08:00:00         2026-06-01 07:00:00     ACTIVE           C07
# 36 2017-01-01 08:00:00         2027-01-08 08:00:00     ACTIVE           C07
# 37 2016-06-30 07:00:00         2026-12-02 08:00:00     ACTIVE           C07
# 38 2017-06-30 07:00:00         2026-06-01 07:00:00     ACTIVE           C07
# 39 2015-08-31 07:00:00         2027-04-28 07:00:00     ACTIVE            FT
# 40 2020-10-15 07:00:00         2027-09-15 07:00:00     ACTIVE           C08
# 41 2020-08-01 07:00:00         2029-02-02 08:00:00     ACTIVE           C08
# 42 2020-12-01 08:00:00         2029-02-02 08:00:00     ACTIVE           C08
# 43 2018-12-31 08:00:00         2028-12-29 08:00:00     ACTIVE           C08
# 44 2018-12-31 08:00:00         2025-12-23 08:00:00     ACTIVE           C08
# 45 2017-12-31 08:00:00         2025-11-15 08:00:00     ACTIVE           C08
# 46 2020-06-01 07:00:00         2025-04-30 07:00:00     ACTIVE           C08
# 47 2020-02-01 08:00:00         2026-03-06 08:00:00     ACTIVE           C08
# 48 2018-09-01 07:00:00         2026-06-01 07:00:00     ACTIVE           C08
# 49 2020-06-01 07:00:00         2026-06-01 07:00:00     ACTIVE           C08
#
#    date_withdrawn withdraw_reason
# 0             NaT             NaN
# 1             NaT             NaN
# 2             NaT             NaN
# 3             NaT             NaN
# 4             NaT             NaN
# 5             NaT             NaN
# 6             NaT             NaN
# 7             NaT             NaN
# 8             NaT             NaN
# 9             NaT             NaN
# 10            NaT             NaN
# 11            NaT             NaN
# 12            NaT             NaN
# 13            NaT             NaN
# 14            NaT             NaN
# 15            NaT             NaN
# 16            NaT             NaN
# 17            NaT             NaN
# 18            NaT             NaN
# 19            NaT             NaN
# 20            NaT             NaN
# 21            NaT             NaN
# 22            NaT             NaN
# 23            NaT             NaN
# 24            NaT             NaN
# 25            NaT             NaN
# 26            NaT             NaN
# 27            NaT             NaN
# 28            NaT             NaN
# 29            NaT             NaN
# 30            NaT             NaN
# 31            NaT             NaN
# 32            NaT             NaN
# 33            NaT             NaN
# 34            NaT             NaN
# 35            NaT             NaN
# 36            NaT             NaN
# 37            NaT             NaN
# 38            NaT             NaN
# 39            NaT             NaN
# 40            NaT             NaN
# 41            NaT             NaN
# 42            NaT             NaN
# 43            NaT             NaN
# 44            NaT             NaN
# 45            NaT             NaN
# 46            NaT             NaN
# 47            NaT             NaN
# 48            NaT             NaN
# 49            NaT             NaN
#
# [50 rows x 24 columns]

# %% [markdown]
# ### Save Processed CSV

# %%
out_path = PROCESSED / "public_queue_clean_combined.csv"
public_all.to_csv(out_path, index=False)

display(Markdown(f"**Saved:** `{out_path}`"))
# Out:
# **Saved:** `C:\Users\danci\Interconnection-Queue-Intelligence\data\processed\public_queue_clean_combined.csv`
